# %%
import sys
import os

sys.path.append(os.getcwd())
from utils.data_util import read_xml, write_binary
from utils.util import load_glove_embeddings, get_similar_words
import spacy
import nltk
import numpy as np
import random

nltk.download('wordnet')
from nltk.corpus import wordnet

# -----CHANGE THESE VALUES ACCORDINGLY BEFORE RUNNING THE SCRIPT----
DATA_TYPE = 'restaurant'
# DATA_TYPE = 'laptops'
TYPE = 'train'
# TYPE = 'test'
# Out:
# [nltk_data] Downloading package wordnet to
# [nltk_data]     /Users/rajdeepsurolia/nltk_data...
# [nltk_data]   Package wordnet is already up-to-date!

# %%
INPUT_FILE_PATH = os.path.join(*[os.path.curdir, 'data/semeval_16', 'ABSA16_Restaurants_Train_SB1_v2.xml'])
OVERSAMPLING = False
PARAPHRASING = False
REDUCED = False
MATCH_TYPE = 'similar'
# MATCH_TYPE = 'synonym'
MAX_MATCHED_WORDS = 3
MINORITY_CLASS = [2]
if PARAPHRASING and MATCH_TYPE == 'similar':
    embedding = load_glove_embeddings()
# -------------------------------------------------------------------

TOTAL_SENTENCE_COUNT = 0
TOTAL_REVIEW_COUNT = 0
TOTAL_AUGMENTED_REVIEW_COUNT = 0
TOTAL_POSITIVE_LABEL_COUNT = 0
TOTAL_NEGATIVE_LABEL_COUNT = 0
TOTAL_NEUTRAL_LABEL_COUNT = 0
TOTAL_NOT_APPLICABLE_LABEL_COUNT = 0
ASPECT_TO_SENTENCE_FREQUENCY = {}

NLP = spacy.load('en')

# %%
def get_one_hot_encoded_sentiment(sentiment):
    p = [0, 0, 0, 0]
    global TOTAL_POSITIVE_LABEL_COUNT
    global TOTAL_NEGATIVE_LABEL_COUNT
    global TOTAL_NEUTRAL_LABEL_COUNT

    if sentiment == 'positive':
        p[0] = 1
        TOTAL_POSITIVE_LABEL_COUNT += 1
    elif sentiment == 'negative':
        p[1] = 1
        TOTAL_NEGATIVE_LABEL_COUNT += 1
    elif sentiment == 'neutral':
        p[2] = 1
        TOTAL_NEUTRAL_LABEL_COUNT += 1
    else:
        p[3] = 1
    return p


def get_categorical_sentiment(sentiment):
    return np.argmax(get_one_hot_encoded_sentiment(sentiment))


def update_aspect_to_sentence_frequency(aspect):
    global ASPECT_TO_SENTENCE_FREQUENCY
    count = ASPECT_TO_SENTENCE_FREQUENCY.get(aspect)
    if count:
        ASPECT_TO_SENTENCE_FREQUENCY[aspect] = count + 1
    else:
        ASPECT_TO_SENTENCE_FREQUENCY[aspect] = 1


def make_flatten_restaurant_data_sentence_level(reviews, mode = 'train'):
    """
    [
    [[aspect1], [review1], [polarity]],
    [[aspect2], [review1], [polarity]]
    ]

    [['food', 'quality'], [[['Judging from previous posts this used to be a good place, but not any longer.'], [0, 0, 0, 1]],
                      ,[['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we
                        were imposing on them and they were very rude.'], [0, 0, 0, 1]],
                      [['They never brought us complimentary noodles, ignored repeated requests for sugar,
                        and threw our dishes on the table.'], [0, 0, 0, 1]],
                      [['The food was lousy - too sweet or too salty and the portions tiny.'], [0, 1, 0, 0]],
                      [['After all that, they complained to me about the small tip.'], [0, 0, 0, 1]],
                      [['Avoid this place!'], [0, 0, 0, 1]]
                      ]
    ]

    This method reads data from the original xml file and formats it in the way shown above. If N is the number of
    possible aspects in this dataset then we repeat or augment each review N times once for each aspect. A review can
    consist of any number of sentences. Each sentence in a review has a label. Labels represent sentiment polarity or
    non applicability of a sentence corresponding to an aspect. For instance, in the above example labels for each
    sentence are generated for the aspect food#quality. Sentences which either do dont talk about this particular aspect
    or any of the possible aspects are labeled as N/A in this datapoint. For instance, the last sentence "Avoid this place"
    is maked as N/A in this datapoint. Although this same sentence will be labelled as NEGATIVE in another datapoint of
    the same review for another aspect restaurant#general.
    :return:
    """

    restaurant_possible_aspects = ['restaurant#general', 'restaurant#prices', 'restaurant#miscellaneous',
                                   'food#prices', 'food#quality', 'food#style_options',
                                   'drinks#prices', 'drinks#quality', 'drinks#style_options',
                                   'ambience#general',
                                   'service#general',
                                   'location#general']

    # we have 22 entities, 9 attributes so total 198 possible aspects
    # but in training data we have only 81 aspects present. In total we selected 116 aspects based our understanding of
    # which entity-attribute pair makes sense.
    laptops_possible_aspects = ['laptop#general',
                                'laptop#price',
                                'laptop#quality',
                                'laptop#operation_performance',
                                'laptop#usability',
                                'laptop#design_features',
                                'laptop#portability',
                                'laptop#connectivity',
                                'laptop#miscellaneous',
                                'display#general',
                                'display#quality',
                                'display#operation_performance',
                                'display#usability',
                                'display#design_features',
                                'display#portability',
                                'display#miscellaneous',
                                'cpu#general',
                                'cpu#price',
                                'cpu#quality',
                                'cpu#operation_performance',
                                'cpu#design_features',
                                'cpu#miscellaneous',
                                'motherboard#general',
                                'motherboard#price',
                                'motherboard#quality',
                                'motherboard#design_features',
                                'motherboard#miscellaneous',
                                'hard_disc#general',
                                'hard_disc#price',
                                'hard_disc#quality',
                                'hard_disc#operation_performance',
                                'hard_disc#design_features',
                                'hard_disc#miscellaneous',
                                'memory#general',
                                'memory#price',
                                'memory#design_features',
                                'memory#miscellaneous',
                                'battery#general',
                                'battery#quality',
                                'battery#operation_performance',
                                'battery#design_features',
                                'battery#miscellaneous',
                                'power_supply#general',
                                'power_supply#price',
                                'power_supply#quality',
                                'power_supply#operation_performance',
                                'power_supply#design_features',
                                'power_supply#miscellaneous',
                                'keyboard#general',
                                'keyboard#quality',
                                'keyboard#operation_performance',
                                'keyboard#usability',
                                'keyboard#design_features',
                                'keyboard#miscellaneous',
                                'mouse#general',
                                'mouse#quality',
                                'mouse#operation_performance',
                                'mouse#usability',
                                'mouse#design_features',
                                'mouse#miscellaneous',
                                'fans_cooling#general',
                                'fans_cooling#quality',
                                'fans_cooling#operation_performance',
                                'fans_cooling#design_features',
                                'fans_cooling#miscellaneous',
                                'optical_drives#general',
                                'optical_drives#quality',
                                'optical_drives#operation_performance',
                                'optical_drives#design_features',
                                'optical_drives#miscellaneous',
                                'ports#general',
                                'ports#quality',
                                'ports#operation_performance',
                                'ports#design_features',
                                'ports#miscellaneous',
                                'graphics#general',
                                'graphics#quality',
                                'graphics#design_features',
                                'graphics#miscellaneous',
                                'multimedia_devices#general',
                                'multimedia_devices#quality',
                                'multimedia_devices#operation_performance',
                                'multimedia_devices#usability',
                                'multimedia_devices#design_features',
                                'multimedia_devices#miscellaneous',
                                'hardware#general',
                                'hardware#quality',
                                'hardware#operation_performance',
                                'hardware#usability',
                                'hardware#design_features',
                                'hardware#miscellaneous',
                                'os#general',
                                'os#quality',
                                'os#operation_performance',
                                'os#usability',
                                'os#design_features',
                                'os#miscellaneous',
                                'software#general',
                                'software#price',
                                'software#quality',
                                'software#operation_performance',
                                'software#usability',
                                'software#design_features',
                                'software#miscellaneous',
                                'warranty#general',
                                'warranty#price',
                                'warranty#miscellaneous',
                                'shipping#general',
                                'shipping#price',
                                'shipping#quality',
                                'shipping#miscellaneous',
                                'support#general',
                                'support#price',
                                'support#quality',
                                'support#miscellaneous',
                                'company#general']

    global TOTAL_SENTENCE_COUNT
    global TOTAL_REVIEW_COUNT
    global TOTAL_AUGMENTED_REVIEW_COUNT
    global TOTAL_POSITIVE_LABEL_COUNT
    global TOTAL_NEGATIVE_LABEL_COUNT
    global TOTAL_NEUTRAL_LABEL_COUNT
    global TOTAL_NOT_APPLICABLE_LABEL_COUNT
    global ASPECT_TO_SENTENCE_FREQUENCY
    global DATA_TYPE

    if DATA_TYPE == 'restaurant':
        possible_aspects = restaurant_possible_aspects
    elif DATA_TYPE == 'laptops':
        possible_aspects = laptops_possible_aspects

    TOTAL_SENTENCE_COUNT = 0
    TOTAL_REVIEW_COUNT = 0
    TOTAL_AUGMENTED_REVIEW_COUNT = 0
    TOTAL_POSITIVE_LABEL_COUNT = 0
    TOTAL_NEGATIVE_LABEL_COUNT = 0
    TOTAL_NEUTRAL_LABEL_COUNT = 0
    TOTAL_NOT_APPLICABLE_LABEL_COUNT = 0
    ASPECT_TO_SENTENCE_FREQUENCY = {}

    dataset = []
    for i, review in enumerate(reviews):
        TOTAL_REVIEW_COUNT += 1
        print('review-' + str(i))

        review_text = []
        aspect_sentence_polarity_map = {}
        sentences = review['sentences']['sentence']
        if isinstance(sentences, dict):
            sentences = [sentences]
        for j, sentence in enumerate(sentences):
            TOTAL_SENTENCE_COUNT += 1
            sentence_text = []
            sentence_text.append(sentence['text'])
            if 'Opinions' in sentence.keys():
                opinions = sentence['Opinions']['Opinion']
                if isinstance(opinions, dict):
                    opinions = [opinions]

                for opinion in opinions:
                    aspect_category = opinion['@category'].lower()
                    update_aspect_to_sentence_frequency(aspect_category)
                    polarity = get_categorical_sentiment(opinion['@polarity'])

                    # Here we are trying to create a map of sentences and aspects. Basicly, for the current review which
                    # sentence is related to which aspect.
                    sentence_polarity = aspect_sentence_polarity_map.get(aspect_category, [])
                    sentence_polarity.append([j, polarity])
                    aspect_sentence_polarity_map[aspect_category] = sentence_polarity
            # else:
            #     # no aspect, contains no sentiment, either out of domain or just some fact
            #     sentence_polarity = aspect_sentence_polarity_map.get('relevance', [])
            #     sentence_polarity.append([j, 3])
            #     aspect_sentence_polarity_map['relevance'] = sentence_polarity

            review_text.append(sentence_text)

        # It could be that a particular review has no sentence for some aspects. Here we are just adding an empty
        # sentence list for such aspects.
        if not REDUCED:
            for aspect in possible_aspects:
                if aspect not in aspect_sentence_polarity_map.keys():
                    aspect_sentence_polarity_map[aspect] = []

        # Now for every possible aspect we will create a datapoint using this particular review.
        for a, sent_polarities in aspect_sentence_polarity_map.items():
            TOTAL_AUGMENTED_REVIEW_COUNT += 1
            aspect_words = []
            aspects = a.split('#')
            aspect_words.extend(aspects[0].split('_'))
            if len(aspects) > 1:
                aspect_words.extend(aspects[1].split('_'))
            augmented_review = []
            augmented_polarity = []
            # check which sentences from the current review are related to this aspect 'a' and has some polarity.
            # Iterate over each sentence from the review and check in the aspect's map whether it is present there
            # or not. If yes, mark the sentence's sentiment polarity accordinly or otherwise mark it N/A(3)
            for j, s in enumerate(review_text):
                updated_polarity = 3
                for sent_polarity in sent_polarities:
                    if j == sent_polarity[0]:
                        # sentence j contains current aspect
                        updated_polarity = sent_polarity[1]
                        break
                if updated_polarity == 3:
                    TOTAL_NOT_APPLICABLE_LABEL_COUNT += 1
                augmented_polarity.append(updated_polarity)
                augmented_review.append(s)
            augmented_datapoint = [aspect_words, augmented_review, augmented_polarity]
            dataset.append(augmented_datapoint)

            if OVERSAMPLING:
                oversampled_datapoints = oversampling(augmented_datapoint)
                if oversampled_datapoints is not None:
                    for oversampled_datapoint in oversampled_datapoints:
                        TOTAL_NEUTRAL_LABEL_COUNT += 1
                        TOTAL_AUGMENTED_REVIEW_COUNT += 1
                        dataset.append(oversampled_datapoint)

        print('---------')
    print(dataset[0])
    print(dataset[1])
    print(dataset[2])
    print(dataset[3])
    print(dataset[4])
    print(dataset[5])
    print(dataset[6])
    print(dataset[7])
    print(dataset[8])
    print(dataset[9])
    print(dataset[10])
    print(dataset[11])
    print(dataset[12])
    print(len(dataset))
    output_file_name = 'formatted_' + DATA_TYPE + '_' + mode + '.pickle'
    write_binary(dataset, filename = output_file_name)
    print('---', mode, '---')
    print('TOTAL_REVIEW_COUNT: ', TOTAL_REVIEW_COUNT)
    print('TOTAL_SENTENCE_COUNT: ', TOTAL_SENTENCE_COUNT)
    print('TOTAL_AUGMENTED_REVIEW_COUNT: ', TOTAL_AUGMENTED_REVIEW_COUNT)
    print('TOTAL_POSITIVE_LABEL_COUNT: ', TOTAL_POSITIVE_LABEL_COUNT)
    print('TOTAL_NEGATIVE_LABEL_COUNT: ', TOTAL_NEGATIVE_LABEL_COUNT)
    print('TOTAL_NEUTRAL_LABEL_COUNT: ', TOTAL_NEUTRAL_LABEL_COUNT)
    print('TOTAL_NOT_APPLICABLE_LABEL_COUNT: ', TOTAL_NOT_APPLICABLE_LABEL_COUNT)
    total_label_count = TOTAL_POSITIVE_LABEL_COUNT + TOTAL_NEGATIVE_LABEL_COUNT + TOTAL_NEUTRAL_LABEL_COUNT + TOTAL_NOT_APPLICABLE_LABEL_COUNT
    print('TOTAL_LABELS: ', total_label_count)
    print('CLASS 0: ', (TOTAL_POSITIVE_LABEL_COUNT / total_label_count) * 100)
    print('CLASS 1: ', (TOTAL_NEGATIVE_LABEL_COUNT / total_label_count) * 100)
    print('CLASS 2: ', (TOTAL_NEUTRAL_LABEL_COUNT / total_label_count) * 100)
    print('CLASS 3: ', (TOTAL_NOT_APPLICABLE_LABEL_COUNT / total_label_count) * 100)
    print('ASPECT_TO_SENTENCE_FREQUENCY:')
    for k, v in ASPECT_TO_SENTENCE_FREQUENCY.items():
        print(k + ": " + str(v))


def oversampling(datapoint):
    augmented = False
    oversampled_datapoints = []
    sent_paraphrases_map = {}
    aspect_words = datapoint[0]
    review = datapoint[1]
    polarity = datapoint[2]
    augmented_review, augmented_polarity = [], []
    for i, sent_polarity in enumerate(polarity):
        if sent_polarity in MINORITY_CLASS:
            sent = review[i]
            augmented_review.append(sent)
            augmented_polarity.append(polarity[i])
            augmented = True
            if PARAPHRASING:
                sent_paraphrases_map[sent[0]] = paraphrase(sent)
    oversampled_datapoints.append([aspect_words, augmented_review, augmented_polarity])

    # permute paraphrased sentences to create new data points
    if PARAPHRASING:
        for i, sent in enumerate(augmented_review):
            paraphrases = sent_paraphrases_map.get(sent[0])
            for p_sent in paraphrases:
                new_review = augmented_review.copy()
                new_review[i] = [p_sent]
                oversampled_datapoints.append([aspect_words, new_review, augmented_polarity])

    if augmented:
        # print('##########################')
        # for dp in oversampled_datapoints:
        #     print(dp)
        # print('##########################')
        return oversampled_datapoints
    else:
        return None


def paraphrase(text):
    """
    This method paraphrases a sentence by replacing nouns and adjectives with synonym words.

    1) find POS tags.
    2) find synonyms for nouns and adjectives.
    3) Make sure to use noun synonyms for nouns and adjective synonyms for adjectives.
    4) permute synonyms to create multiple paraphrases.
    :param text:
    :return:
    """

    word_to_synonym_map = {}
    paraphrases = []
    sentence = text[0]

    doc = NLP(sentence)
    for token in doc:
        word = token.text
        word_pos = token.pos_
        if word_pos == 'NOUN':
            synonyms = get_matched_words(word, word_pos = 'n')
            word_to_synonym_map[word] = synonyms
        elif word_pos == 'ADJ':
            synonyms = get_matched_words(word, word_pos = 'a')
            word_to_synonym_map[word] = synonyms

    for word, synonyms in word_to_synonym_map.items():
        for synonym in synonyms:
            paraphrases.append(sentence.replace(word, synonym))

    print('##########################')
    for dp in paraphrases:
        print(dp)
    print('##########################')
    return paraphrases


def limit_matched_words(words):
    matched_words = set()
    count = MAX_MATCHED_WORDS
    for word in words:
        if count > 0:
            matched_words.add(word)
            count -= 1
        else:
            break
    return matched_words


def get_matched_words(word, word_pos):
    matched_words = set()
    if MATCH_TYPE == 'synonym':
        matched_words = limit_matched_words(get_synonyms(word, word_pos))
    elif MATCH_TYPE == 'similar':
        matched_words = limit_matched_words(get_similar_words_using_embedding(word))
    return matched_words


def get_similar_words_using_embedding(word):
    similar_words = get_similar_words(word, embedding = embedding)
    reduced_similar_words = set()
    for similar_word in similar_words:
        if word not in similar_word[0]:
            reduced_similar_words.add(similar_word[0])
    return reduced_similar_words


def get_synonyms(word, word_pos):
    synonyms = set()
    syns = wordnet.synsets(word)
    for syn in syns:
        syn_pos = syn.name().split('.')[1]
        if syn_pos == word_pos:
            for l in syn.lemmas():
                synonyms.add(' '.join(l.name().split('_')))
    return synonyms


def make_split(doc):
    test_reviews = []
    val_reviews = []
    reviews = doc['Reviews']['Review']
    for i, review in enumerate(reviews):
        r = random.random()
        if r < 0.5:
            test_reviews.append(review)
        else:
            val_reviews.append(review)
    return test_reviews, val_reviews

# %%
if TYPE == 'train':
        doc = read_xml(INPUT_FILE_PATH)
        reviews = doc['Reviews']['Review']
        make_flatten_restaurant_data_sentence_level(reviews, mode = 'train')
elif TYPE == 'test':
    doc = read_xml(INPUT_FILE_PATH)
    test_reviews, val_reviews = make_split(doc)
    make_flatten_restaurant_data_sentence_level(test_reviews, mode = 'test')
    make_flatten_restaurant_data_sentence_level(val_reviews, mode = 'val')
# Out:
# review-0
# ---------
# review-1
# ---------
# review-2
# ---------
# review-3
# ---------
# review-4
# ---------
# review-5
# ---------
# review-6
# ---------
# review-7
# ---------
# review-8
# ---------
# review-9
# ---------
# review-10
# ---------
# review-11
# ---------
# review-12
# ---------
# review-13
# ---------
# review-14
# ---------
# review-15
# ---------
# review-16
# ---------
# review-17
# ---------
# review-18
# ---------
# review-19
# ---------
# review-20
# ---------
# review-21
# ---------
# review-22
# ---------
# review-23
# ---------
# review-24
# ---------
# review-25
# ---------
# review-26
# ---------
# review-27
# ---------
# review-28
# ---------
# review-29
# ---------
# review-30
# ---------
# review-31
# ---------
# review-32
# ---------
# review-33
# ---------
# review-34
# ---------
# review-35
# ---------
# review-36
# ---------
# review-37
# ---------
# review-38
# ---------
# review-39
# ---------
# review-40
# ---------
# review-41
# ---------
# review-42
# ---------
# review-43
# ---------
# review-44
# ---------
# review-45
# ---------
# review-46
# ---------
# review-47
# ---------
# review-48
# ---------
# review-49
# ---------
# review-50
# ---------
# review-51
# ---------
# review-52
# ---------
# review-53
# ---------
# review-54
# ---------
# review-55
# ---------
# review-56
# ---------
# review-57
# ---------
# review-58
# ---------
# review-59
# ---------
# review-60
# ---------
# review-61
# ---------
# review-62
# ---------
# review-63
# ---------
# review-64
# ---------
# review-65
# ---------
# review-66
# ---------
# review-67
# ---------
# review-68
# ---------
# review-69
# ---------
# review-70
# ---------
# review-71
# ---------
# review-72
# ---------
# review-73
# ---------
# review-74
# ---------
# review-75
# ---------
# review-76
# ---------
# review-77
# ---------
# review-78
# ---------
# review-79
# ---------
# review-80
# ---------
# review-81
# ---------
# review-82
# ---------
# review-83
# ---------
# review-84
# ---------
# review-85
# ---------
# review-86
# ---------
# review-87
# ---------
# review-88
# ---------
# review-89
# ---------
# review-90
# ---------
# review-91
# ---------
# review-92
# ---------
# review-93
# ---------
# review-94
# ---------
# review-95
# ---------
# review-96
# ---------
# review-97
# ---------
# review-98
# ---------
# review-99
# ---------
# review-100
# ---------
# review-101
# ---------
# review-102
# ---------
# review-103
# ---------
# review-104
# ---------
# review-105
# ---------
# review-106
# ---------
# review-107
# ---------
# review-108
# ---------
# review-109
# ---------
# review-110
# ---------
# review-111
# ---------
# review-112
# ---------
# review-113
# ---------
# review-114
# ---------
# review-115
# ---------
# review-116
# ---------
# review-117
# ---------
# review-118
# ---------
# review-119
# ---------
# review-120
# ---------
# review-121
# ---------
# review-122
# ---------
# review-123
# ---------
# review-124
# ---------
# review-125
# ---------
# review-126
# ---------
# review-127
# ---------
# review-128
# ---------
# review-129
# ---------
# review-130
# ---------
# review-131
# ---------
# review-132
# ---------
# review-133
# ---------
# review-134
# ---------
# review-135
# ---------
# review-136
# ---------
# review-137
# ---------
# review-138
# ---------
# review-139
# ---------
# review-140
# ---------
# review-141
# ---------
# review-142
# ---------
# review-143
# ---------
# review-144
# ---------
# review-145
# ---------
# review-146
# ---------
# review-147
# ---------
# review-148
# ---------
# review-149
# ---------
# review-150
# ---------
# review-151
# ---------
# review-152
# ---------
# review-153
# ---------
# review-154
# ---------
# review-155
# ---------
# review-156
# ---------
# review-157
# ---------
# review-158
# ---------
# review-159
# ---------
# review-160
# ---------
# review-161
# ---------
# review-162
# ---------
# review-163
# ---------
# review-164
# ---------
# review-165
# ---------
# review-166
# ---------
# review-167
# ---------
# review-168
# ---------
# review-169
# ---------
# review-170
# ---------
# review-171
# ---------
# review-172
# ---------
# review-173
# ---------
# review-174
# ---------
# review-175
# ---------
# review-176
# ---------
# review-177
# ---------
# review-178
# ---------
# review-179
# ---------
# review-180
# ---------
# review-181
# ---------
# review-182
# ---------
# review-183
# ---------
# review-184
# ---------
# review-185
# ---------
# review-186
# ---------
# review-187
# ---------
# review-188
# ---------
# review-189
# ---------
# review-190
# ---------
# review-191
# ---------
# review-192
# ---------
# review-193
# ---------
# review-194
# ---------
# review-195
# ---------
# review-196
# ---------
# review-197
# ---------
# review-198
# ---------
# review-199
# ---------
# review-200
# ---------
# review-201
# ---------
# review-202
# ---------
# review-203
# ---------
# review-204
# ---------
# review-205
# ---------
# review-206
# ---------
# review-207
# ---------
# review-208
# ---------
# review-209
# ---------
# review-210
# ---------
# review-211
# ---------
# review-212
# ---------
# review-213
# ---------
# review-214
# ---------
# review-215
# ---------
# review-216
# ---------
# review-217
# ---------
# review-218
# ---------
# review-219
# ---------
# review-220
# ---------
# review-221
# ---------
# review-222
# ---------
# review-223
# ---------
# review-224
# ---------
# review-225
# ---------
# review-226
# ---------
# review-227
# ---------
# review-228
# ---------
# review-229
# ---------
# review-230
# ---------
# review-231
# ---------
# review-232
# ---------
# review-233
# ---------
# review-234
# ---------
# review-235
# ---------
# review-236
# ---------
# review-237
# ---------
# review-238
# ---------
# review-239
# ---------
# review-240
# ---------
# review-241
# ---------
# review-242
# ---------
# review-243
# ---------
# review-244
# ---------
# review-245
# ---------
# review-246
# ---------
# review-247
# ---------
# review-248
# ---------
# review-249
# ---------
# review-250
# ---------
# review-251
# ---------
# review-252
# ---------
# review-253
# ---------
# review-254
# ---------
# review-255
# ---------
# review-256
# ---------
# review-257
# ---------
# review-258
# ---------
# review-259
# ---------
# review-260
# ---------
# review-261
# ---------
# review-262
# ---------
# review-263
# ---------
# review-264
# ---------
# review-265
# ---------
# review-266
# ---------
# review-267
# ---------
# review-268
# ---------
# review-269
# ---------
# review-270
# ---------
# review-271
# ---------
# review-272
# ---------
# review-273
# ---------
# review-274
# ---------
# review-275
# ---------
# review-276
# ---------
# review-277
# ---------
# review-278
# ---------
# review-279
# ---------
# review-280
# ---------
# review-281
# ---------
# review-282
# ---------
# review-283
# ---------
# review-284
# ---------
# review-285
# ---------
# review-286
# ---------
# review-287
# ---------
# review-288
# ---------
# review-289
# ---------
# review-290
# ---------
# review-291
# ---------
# review-292
# ---------
# review-293
# ---------
# review-294
# ---------
# review-295
# ---------
# review-296
# ---------
# review-297
# ---------
# review-298
# ---------
# review-299
# ---------
# review-300
# ---------
# review-301
# ---------
# review-302
# ---------
# review-303
# ---------
# review-304
# ---------
# review-305
# ---------
# review-306
# ---------
# review-307
# ---------
# review-308
# ---------
# review-309
# ---------
# review-310
# ---------
# review-311
# ---------
# review-312
# ---------
# review-313
# ---------
# review-314
# ---------
# review-315
# ---------
# review-316
# ---------
# review-317
# ---------
# review-318
# ---------
# review-319
# ---------
# review-320
# ---------
# review-321
# ---------
# review-322
# ---------
# review-323
# ---------
# review-324
# ---------
# review-325
# ---------
# review-326
# ---------
# review-327
# ---------
# review-328
# ---------
# review-329
# ---------
# review-330
# ---------
# review-331
# ---------
# review-332
# ---------
# review-333
# ---------
# review-334
# ---------
# review-335
# ---------
# review-336
# ---------
# review-337
# ---------
# review-338
# ---------
# review-339
# ---------
# review-340
# ---------
# review-341
# ---------
# review-342
# ---------
# review-343
# ---------
# review-344
# ---------
# review-345
# ---------
# review-346
# ---------
# review-347
# ---------
# review-348
# ---------
# review-349
# ---------
# [['restaurant', 'general'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [1, 3, 3, 3, 3, 1]]
# [['service', 'general'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 1, 1, 3, 1, 3]]
# [['food', 'quality'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 3, 3, 1, 3, 3]]
# [['food', 'style', 'options'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 3, 3, 1, 3, 3]]
# [['restaurant', 'prices'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 3, 3, 3, 3, 3]]
# [['restaurant', 'miscellaneous'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 3, 3, 3, 3, 3]]
# [['food', 'prices'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 3, 3, 3, 3, 3]]
# [['drinks', 'prices'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 3, 3, 3, 3, 3]]
# [['drinks', 'quality'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 3, 3, 3, 3, 3]]
# [['drinks', 'style', 'options'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 3, 3, 3, 3, 3]]
# [['ambience', 'general'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 3, 3, 3, 3, 3]]
# [['location', 'general'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [3, 3, 3, 3, 3, 3]]
# [['food', 'quality'], [['I have eaten at Saul, many times, the food is always consistently, outrageously good.'], ['Saul is the best restaurant on Smith Street and in Brooklyn.'], ['The duck confit is always amazing and the foie gras terrine with figs was out of this world.'], ['The wine list is interesting and has many good values.'], ['For the price, you cannot eat this well in Manhattan.']], [0, 3, 0, 3, 0]]
# 4200
# --- train ---
# TOTAL_REVIEW_COUNT:  350
# TOTAL_SENTENCE_COUNT:  2000
# TOTAL_AUGMENTED_REVIEW_COUNT:  4200
# TOTAL_POSITIVE_LABEL_COUNT:  1657
# TOTAL_NEGATIVE_LABEL_COUNT:  749
# TOTAL_NEUTRAL_LABEL_COUNT:  101
# TOTAL_NOT_APPLICABLE_LABEL_COUNT:  21742
# TOTAL_LABELS:  24249
# CLASS 0:  6.833271475112376
# CLASS 1:  3.088787166481092
# CLASS 2:  0.41651202111427277
# CLASS 3:  89.66142933729226
# ASPECT_TO_SENTENCE_FREQUENCY:
# restaurant#general: 422
# service#general: 449
# food#quality: 849
# food#style_options: 137
# drinks#style_options: 32
# drinks#prices: 20
# restaurant#prices: 80
# restaurant#miscellaneous: 98
# ambience#general: 255
# food#prices: 90
# location#general: 28
# drinks#quality: 47

# %%
from config.settings import WORD_FREQ_FILE, VOCAB_TO_CODE_FILE, CODE_TO_VOCAB_FILE, CODE_TO_EMBED_FILE
from utils.data_util import read_binary, write_binary
from utils.util import load_glove_embeddings, load_fastText_embeddings, load_oov_fastText_embeddings
from collections import defaultdict
import random

# %%
# ---SCRIPT DEPENDENCIES----
# python -m spacy download en
# --------------------------

# -----CHANGE THESE VALUES ACCORDINGLY BEFORE RUNNING THE SCRIPT-----
TYPE = 'train'
# TYPE = 'test'
# TYPE = 'val'
FILE_NAME = 'restaurant'
# FILE_NAME = 'laptops'
EMBEDDING_TYPE = 'fasttext'
# EMBEDDING_TYPE = 'glove'
# EMBEDDING_TYPE = None
# -------------------------------------------------------------------
FORMATTED_FILE_NAME = 'formatted_' + FILE_NAME + '_' + TYPE + '.pickle'
PROCESSED_FILE_NAME = 'processed_' + TYPE + '.pickle'

EMBEDDING_DIMENSION = 300
MAX_VOCAB_SIZE = 50001
UNKNOWN_EMBEDDING = np.random.randn(EMBEDDING_DIMENSION)
PAD = 0
PAD_EMBEDDING = np.zeros(EMBEDDING_DIMENSION)
NLP = spacy.load('en')

HOTELS_ASPECT_WORDS = ['hotel', 'general', 'prices', 'design', 'features', 'cleanliness', 'comfort',
                       'quality', 'style', 'options', 'miscellaneous', 'rooms', 'room', 'amenities', 'facilities',
                       'service', 'location', 'food', 'drinks', 'Hotel', 'General', 'Prices', 'Design', 'Features',
                       'Cleanliness', 'Comfort', 'Quality', 'Style', 'Options', 'Miscellaneous', 'Rooms', 'Room',
                       'Amenities', 'Facilities', 'Service', 'Location', 'Food', 'Drinks']

HOTELS_ALL_POSSIBLE_ASPECTS = [['hotel', 'general'], ['hotel', 'prices'], ['hotel', 'design', 'features'],
                               ['hotel', 'cleaniness'], ['hotel', 'comfort'], ['hotel', 'quality'],
                               ['hotel', 'miscellaneous'],
                               ['rooms', 'general'], ['rooms', 'prices'], ['rooms', 'design', 'features'],
                               ['rooms', 'cleaniness'], ['rooms', 'comfort'], ['rooms', 'quality'],
                               ['rooms', 'miscellaneous'],
                               ['room', 'amenities', 'general'], ['room', 'amenities', 'prices'],
                               ['room', 'amenities', 'design', 'features'],
                               ['room', 'amenities', 'cleaniness'], ['room', 'amenities', 'comfort'],
                               ['room', 'amenities', 'quality'],
                               ['room', 'amenities', 'miscellaneous'], ['service', 'general'], ['location', 'general'],
                               ['food', 'drinks', 'prices'], ['food', 'drinks', 'quality'],
                               ['food', 'drinks', 'style', 'options']]

RESTAURANT_ASPECT_WORDS = ['restaurant', 'general', 'prices', 'miscellaneous', 'food', 'quality', 'style', 'options',
                           'drinks', 'ambience', 'service', 'location', 'Restaurant', 'General', 'Prices',
                           'Miscellaneous',
                           'Food',
                           'Quality', 'Style', 'Options', 'Drinks', 'Ambience', 'Service', 'Location']

RESTAURANT_ALL_POSSIBLE_ASPECTS = [['restaurant', 'general'], ['restaurant', 'prices'], ['restaurant', 'miscellaneous'],
                                   ['food', 'prices'], ['food', 'quality'], ['food', 'style', 'options'],
                                   ['drinks', 'prices'], ['drinks', 'quality'], ['drinks', 'style', 'options'],
                                   ['ambience', 'general'],
                                   ['service', 'general'],
                                   ['location', 'general']]

RESTAURANT_ASPECT_WORD_INDEX_MAP = {
    'foodstyleoptions': 0,
    'foodquality': 1,
    'drinksprices': 2,
    'foodprices': 3,
    'ambiencegeneral': 4,
    'drinksstyleoptions': 5,
    'locationgeneral': 6,
    'drinksquality': 7,
    'restaurantprices': 8,
    'restaurantmiscellaneous': 9,
    'servicegeneral': 10,
    'restaurantgeneral': 11,
    'none': 12
}

RESTAURANT_INDEX_TO_ASPECT_WORD_MAP = {
    0: 'foodstyleoptions',
    1: 'foodquality',
    2: 'drinksprices',
    3: 'foodprices',
    4: 'ambiencegeneral',
    5: 'drinksstyleoptions',
    6: 'locationgeneral',
    7: 'drinksquality',
    8: 'restaurantprices',
    9: 'restaurantmiscellaneous',
    10: 'servicegeneral',
    11: 'restaurantgeneral',
    12: 'none'
}

LAPTOPS_ASPECT_WORDS = ['laptop', 'display', 'cpu', 'motherboard', 'hard', 'disc', 'memory', 'battery', 'power',
                        'supply', 'keyboard', 'mouse', 'fan', 'fans', 'cooling', 'optical', 'drives', 'drive', 'ports',
                        'graphics', 'multimedia', 'devices', 'device', 'hardware', 'os', 'software', 'warranty',
                        'shipping', 'support', 'company', 'general', 'price', 'quality', 'operation', 'performance',
                        'usability', 'design', 'features', 'portability', 'connectivity', 'miscellaneous',
                        'Laptop', 'Display', 'CPU', 'Cpu', 'Motherboard', 'Hard', 'Disc', 'Memory', 'Battery', 'Power',
                        'Supply', 'Keyboard', 'Mouse', 'Fan', 'Fans', 'Cooling', 'Optical', 'Drives', 'Drive', 'Ports',
                        'Graphics', 'Multimedia', 'Devices', 'Device', 'Hardware', 'OS', 'Os', 'Software', 'Warranty',
                        'Shipping', 'Support', 'Company', 'General', 'Price', 'Quality', 'Operation', 'Performance',
                        'Usability', 'Design', 'Features', 'Portability', 'Connectivity', 'Miscellaneous'
                        ]

LAPTOPS_ALL_POSSIBLE_ASPECTS = [['laptop', 'general'], ['laptop', 'operation', 'performance'], ['laptop', 'usability'],
                                ['laptop', 'portability'], ['laptop', 'price'], ['laptop', 'quality'],
                                ['laptop', 'design', 'features'], ['laptop', 'miscellaneous'],
                                ['laptop', 'connectivity'],
                                ['display', 'usability'], ['display', 'design', 'features'], ['display', 'quality'],
                                ['display', 'general'], ['display', 'operation', 'performance'],
                                ['cpu', 'operation', 'performance'], ['cpu', 'quality'], ['cpu', 'miscellaneous'],
                                ['cpu', 'design', 'features'],
                                ['motherboard', 'quality'],
                                ['hard', 'disc', 'design', 'features'], ['hard', 'disc', 'quality'],
                                ['memory', 'design', 'features'],
                                ['battery', 'quality'], ['battery', 'miscellaneous'],
                                ['battery', 'operation', 'performance'],
                                ['power', 'supply', 'quality'], ['power', 'supply', 'operation', 'performance'],
                                ['power', 'supply', 'design', 'features'], ['power', 'supply', 'miscellaneous'],
                                ['keyboard', 'design', 'features'], ['keyboard', 'general'], ['keyboard', 'usability'],
                                ['keyboard', 'quality'], ['keyboard', 'operation', 'performance'],
                                ['mouse', 'design', 'features'], ['mouse', 'quality'],
                                ['mouse', 'operation', 'performance'],
                                ['mouse', 'usability'], ['mouse', 'general'],
                                ['fans', 'cooling', 'design', 'features'], ['fans', 'cooling', 'quality'],
                                ['fans', 'cooling', 'operation', 'performance'],
                                ['optical', 'drives', 'quality'], ['optical', 'drives', 'operation', 'performance'],
                                ['ports', 'quality'], ['ports', 'design', 'features'],
                                ['ports', 'operation', 'performance'],
                                ['graphics', 'quality'], ['graphics', 'general'], ['graphics', 'design_features'],
                                ['graphics', 'miscellaneous'],
                                ['multimedia', 'devices', 'usability'], ['multimedia', 'devices', 'miscellaneous'],
                                ['multimedia', 'devices', 'operation', 'performance'],
                                ['multimedia', 'devices', 'quality'],
                                ['multimedia', 'devices', 'general'], ['multimedia', 'devices', 'design', 'features'],
                                ['hardware', 'quality'], ['hardware', 'general'],
                                ['hardware', 'operation', 'performance'],
                                ['os', 'design', 'features'], ['os', 'general'], ['os', 'usability'],
                                ['os', 'miscellaneous'],
                                ['os', 'operation', 'performance'], ['os', 'quality'],
                                ['software', 'miscellaneous'], ['software', 'general'], ['software', 'quality'],
                                ['software', 'usability'], ['software', 'design', 'features'],
                                ['software', 'operation', 'performance'], ['software', 'price'],
                                ['warranty', 'general'], ['warranty', 'price'],
                                ['shipping', 'quality'], ['shipping', 'price'],
                                ['support', 'quality'], ['support', 'miscellaneous'], ['support', 'price'],
                                ['company', 'general']]

LAPTOPS_ASPECT_WORD_INDEX_MAP = {
    'laptopgeneral': 0,
    'laptopprice': 1,
    'laptopquality': 2,
    'laptopoperationperformance': 3,
    'laptopusability': 4,
    'laptopdesignfeatures': 5,
    'laptopportability': 6,
    'laptopconnectivity': 7,
    'laptopmiscellaneous': 8,
    'displaygeneral': 9,
    'displayquality': 10,
    'displayoperationperformance': 11,
    'displayusability': 12,
    'displaydesignfeatures': 13,
    'displayportability': 14,
    'displaymiscellaneous': 15,
    'cpugeneral': 16,
    'cpuprice': 17,
    'cpuquality': 18,
    'cpuoperationperformance': 19,
    'cpudesignfeatures': 20,
    'cpumiscellaneous': 21,
    'motherboardgeneral': 22,
    'motherboardprice': 23,
    'motherboardquality': 24,
    'motherboarddesignfeatures': 25,
    'motherboardmiscellaneous': 26,
    'harddiscgeneral': 27,
    'harddiscprice': 28,
    'harddiscquality': 29,
    'harddiscoperationperformance': 30,
    'harddiscdesignfeatures': 31,
    'harddiscmiscellaneous': 32,
    'memorygeneral': 33,
    'memoryprice': 34,
    'memorydesignfeatures': 35,
    'memorymiscellaneous': 36,
    'batterygeneral': 37,
    'batteryquality': 38,
    'batteryoperationperformance': 39,
    'batterydesignfeatures': 40,
    'batterymiscellaneous': 41,
    'powersupplygeneral': 42,
    'powersupplyprice': 43,
    'powersupplyquality': 44,
    'powersupplyoperationperformance': 45,
    'powersupplydesignfeatures': 46,
    'powersupplymiscellaneous': 47,
    'keyboardgeneral': 48,
    'keyboardquality': 49,
    'keyboardoperationperformance': 50,
    'keyboardusability': 51,
    'keyboarddesignfeatures': 52,
    'keyboardmiscellaneous': 53,
    'mousegeneral': 54,
    'mousequality': 55,
    'mouseoperationperformance': 56,
    'mouseusability': 57,
    'mousedesignfeatures': 58,
    'mousemiscellaneous': 59,
    'fanscoolinggeneral': 60,
    'fanscoolingquality': 61,
    'fanscoolingoperationperformance': 62,
    'fanscoolingdesignfeatures': 63,
    'fanscoolingmiscellaneous': 64,
    'opticaldrivesgeneral': 65,
    'opticaldrivesquality': 66,
    'opticaldrivesoperationperformance': 67,
    'opticaldrivesdesignfeatures': 68,
    'opticaldrivesmiscellaneous': 69,
    'portsgeneral': 70,
    'portsquality': 71,
    'portsoperationperformance': 72,
    'portsdesignfeatures': 73,
    'portsmiscellaneous': 74,
    'graphicsgeneral': 75,
    'graphicsquality': 76,
    'graphicsdesignfeatures': 77,
    'graphicsmiscellaneous': 78,
    'multimediadevicesgeneral': 79,
    'multimediadevicesquality': 80,
    'multimediadevicesoperationperformance': 81,
    'multimediadevicesusability': 82,
    'multimediadevicesdesignfeatures': 83,
    'multimediadevicesmiscellaneous': 84,
    'hardwaregeneral': 85,
    'hardwarequality': 86,
    'hardwareoperationperformance': 87,
    'hardwareusability': 88,
    'hardwaredesignfeatures': 89,
    'hardwaremiscellaneous': 90,
    'osgeneral': 91,
    'osquality': 92,
    'osoperationperformance': 93,
    'osusability': 94,
    'osdesignfeatures': 95,
    'osmiscellaneous': 96,
    'softwaregeneral': 97,
    'softwareprice': 98,
    'softwarequality': 99,
    'softwareoperationperformance': 100,
    'softwareusability': 101,
    'softwaredesignfeatures': 102,
    'softwaremiscellaneous': 103,
    'warrantygeneral': 104,
    'warrantyprice': 105,
    'warrantymiscellaneous': 106,
    'shippinggeneral': 107,
    'shippingprice': 108,
    'shippingquality': 109,
    'shippingmiscellaneous': 110,
    'supportgeneral': 111,
    'supportprice': 112,
    'supportquality': 113,
    'supportmiscellaneous': 114,
    'companygeneral': 115,
    'none': 116
}

LAPTOPS_INDEX_TO_ASPECT_WORD_MAP = {
    0: 'laptopgeneral',
    1: 'laptopprice',
    2: 'laptopquality',
    3: 'laptopoperationperformance',
    4: 'laptopusability',
    5: 'laptopdesignfeatures',
    6: 'laptopportability',
    7: 'laptopconnectivity',
    8: 'laptopmiscellaneous',
    9: 'displaygeneral',
    10: 'displayquality',
    11: 'displayoperationperformance',
    12: 'displayusability',
    13: 'displaydesignfeatures',
    14: 'displayportability',
    15: 'displaymiscellaneous',
    16: 'cpugeneral',
    17: 'cpuprice',
    18: 'cpuquality',
    19: 'cpuoperationperformance',
    20: 'cpudesignfeatures',
    21: 'cpumiscellaneous',
    22: 'motherboardgeneral',
    23: 'motherboardprice',
    24: 'motherboardquality',
    25: 'motherboarddesignfeatures',
    26: 'motherboardmiscellaneous',
    27: 'harddiscgeneral',
    28: 'harddiscprice',
    29: 'harddiscquality',
    30: 'harddiscoperationperformance',
    31: 'harddiscdesignfeatures',
    32: 'harddiscmiscellaneous',
    33: 'memorygeneral',
    34: 'memoryprice',
    35: 'memorydesignfeatures',
    36: 'memorymiscellaneous',
    37: 'batterygeneral',
    38: 'batteryquality',
    39: 'batteryoperationperformance',
    40: 'batterydesignfeatures',
    41: 'batterymiscellaneous',
    42: 'powersupplygeneral',
    43: 'powersupplyprice',
    44: 'powersupplyquality',
    45: 'powersupplyoperationperformance',
    46: 'powersupplydesignfeatures',
    47: 'powersupplymiscellaneous',
    48: 'keyboardgeneral',
    49: 'keyboardquality',
    50: 'keyboardoperationperformance',
    51: 'keyboardusability',
    52: 'keyboarddesignfeatures',
    53: 'keyboardmiscellaneous',
    54: 'mousegeneral',
    55: 'mousequality',
    56: 'mouseoperationperformance',
    57: 'mouseusability',
    58: 'mousedesignfeatures',
    59: 'mousemiscellaneous',
    60: 'fanscoolinggeneral',
    61: 'fanscoolingquality',
    62: 'fanscoolingoperationperformance',
    63: 'fanscoolingdesignfeatures',
    64: 'fanscoolingmiscellaneous',
    65: 'opticaldrivesgeneral',
    66: 'opticaldrivesquality',
    67: 'opticaldrivesoperationperformance',
    68: 'opticaldrivesdesignfeatures',
    69: 'opticaldrivesmiscellaneous',
    70: 'portsgeneral',
    71: 'portsquality',
    72: 'portsoperationperformance',
    73: 'portsdesignfeatures',
    74: 'portsmiscellaneous',
    75: 'graphicsgeneral',
    76: 'graphicsquality',
    77: 'graphicsdesignfeatures',
    78: 'graphicsmiscellaneous',
    79: 'multimediadevicesgeneral',
    80: 'multimediadevicesquality',
    81: 'multimediadevicesoperationperformance',
    82: 'multimediadevicesusability',
    83: 'multimediadevicesdesignfeatures',
    84: 'multimediadevicesmiscellaneous',
    85: 'hardwaregeneral',
    86: 'hardwarequality',
    87: 'hardwareoperationperformance',
    88: 'hardwareusability',
    89: 'hardwaredesignfeatures',
    90: 'hardwaremiscellaneous',
    91: 'osgeneral',
    92: 'osquality',
    93: 'osoperationperformance',
    94: 'osusability',
    95: 'osdesignfeatures',
    96: 'osmiscellaneous',
    97: 'softwaregeneral',
    98: 'softwareprice',
    99: 'softwarequality',
    100: 'softwareoperationperformance',
    101: 'softwareusability',
    102: 'softwaredesignfeatures',
    103: 'softwaremiscellaneous',
    104: 'warrantygeneral',
    105: 'warrantyprice',
    106: 'warrantymiscellaneous',
    107: 'shippinggeneral',
    108: 'shippingprice',
    109: 'shippingquality',
    110: 'shippingmiscellaneous',
    111: 'supportgeneral',
    112: 'supportprice',
    113: 'supportquality',
    114: 'supportmiscellaneous',
    115: 'companygeneral',
    116: 'none'
}

# %%
def build_word_frequency_distribution():
    """
    1. Extract tokens from the review text
    2. Calculate frequency of each token
    3. Create a freq dict and store it in a file

    :return: A dict of <token, freq>
    """
    try:
        freq_dist_f = read_binary(WORD_FREQ_FILE)
        print('frequency distribution loaded')
        return freq_dist_f
    except IOError:
        pass

    print('building frequency distribution')
    freq = defaultdict(int)
    if FILE_NAME == 'restaurant':
        for aspect_word in RESTAURANT_ASPECT_WORDS:
            freq[aspect_word] += 1
    elif FILE_NAME == 'laptops':
        for aspect_word in LAPTOPS_ASPECT_WORDS:
            freq[aspect_word] += 1

    files = [FORMATTED_FILE_NAME]
    #if EMBEDDING_TYPE == 'fasttext':
        #files.append(FORMATTED_FILE_NAME.replace('train', 'test'))
        #files.append(FORMATTED_FILE_NAME.replace('train', 'val'))

    for file_path in files:
        print('building vocab from file - ' + file_path)
        for i, review in enumerate(read_binary(file_path)):
            sentences = review[1]

            for sent in sentences:
                tokens = NLP.tokenizer(sent[0])
                for token in tokens:
                    freq[token.orth_] += 1
                if i % 100 == 0:
                    write_binary(freq, WORD_FREQ_FILE)
                    print('dump at {}'.format(i))
            write_binary(freq, WORD_FREQ_FILE)
    return freq


def build_vocabulary(lower = 1, n = MAX_VOCAB_SIZE):
    """
    1. Get word frequency distribution
    2. Sort is based on word frequencies
    3. Make a vocab dist using the most frequent words
    4. Store vocab dist in a file in format <word, identifier>

    :param lower: Identifiers below this are reserved
    :param n: Number of unique expected words
    :return: A dict of vocabulary words and an assigned identifier
    """

    try:
        vocab_to_code = read_binary(VOCAB_TO_CODE_FILE)
        code_to_vocab = read_binary(CODE_TO_VOCAB_FILE)
        print('vocabulary loaded')
        return vocab_to_code, code_to_vocab
    except IOError:
        print('building vocabulary')
    freq = build_word_frequency_distribution()

    # get glove embeddings
    print('loading embeddings')
    if EMBEDDING_TYPE == 'glove':
        word_to_embeddings = load_glove_embeddings()
    elif EMBEDDING_TYPE == 'fasttext':
        word_to_embeddings = load_oov_fastText_embeddings()
    else:
        word_to_embeddings = {}

    # sorting words in ascending order based on frequency and then pick top n words
    top_words = list(sorted(freq.items(), key = lambda x: -x[1]))[:n - lower + 1]
    # create optimum vocab size
    print('Vocab count : ' + str(len(top_words)))
    # global MAX_VOCAB_SIZE
    # global UNKNOWN
    max_vocab_size = len(top_words) + 2
    unknown = max_vocab_size - 1
    vocab_to_code = {}
    code_to_vocab = {}

    # an array of embeddings with index referring to the vocab code. First and last index is
    # reserved for padding and unknown words respectively.
    code_to_embed = np.zeros(shape = (max_vocab_size, EMBEDDING_DIMENSION), dtype = np.float32)
    code_to_embed[PAD] = PAD_EMBEDDING
    code_to_embed[unknown] = UNKNOWN_EMBEDDING
    vocab_to_code['<UNK>'] = unknown
    code_to_vocab[unknown] = '<UNK>'
    vocab_to_code['<PAD>'] = PAD
    code_to_vocab[PAD] = '<PAD>'

    # lower vocab indexes are reserved for padding and unknown words
    i = lower
    for w, freq in top_words:
        vocab_to_code[w] = i
        code_to_vocab[i] = w
        try:
            if EMBEDDING_TYPE == 'glove':
                embedding = word_to_embeddings.word_vec(w)
            elif EMBEDDING_TYPE == 'fasttext':
                embedding = word_to_embeddings.get_word_vector(w)
        except KeyError:
            embedding = UNKNOWN_EMBEDDING

        if EMBEDDING_TYPE in ['glove', 'fasttext']:
            code_to_embed[i] = embedding
        i += 1
    write_binary(vocab_to_code, VOCAB_TO_CODE_FILE)
    write_binary(code_to_vocab, CODE_TO_VOCAB_FILE)
    write_binary(code_to_embed, CODE_TO_EMBED_FILE)
    return vocab_to_code, code_to_vocab


def get_uncoded_data(code_to_vocab, datapoint):
    aspect_words = []
    review = []
    aspect_codes = datapoint[0]
    coded_sentences = datapoint[1]
    polarities = datapoint[2]

    for aspect_code in aspect_codes:
        aspect_words.append(code_to_vocab.get(aspect_code))

    for sentence in coded_sentences:
        sent_words = []
        for coded_word in sentence:
            sent_words.append(code_to_vocab.get(coded_word))
        review.append(sent_words)
    x = [aspect_words, review, polarities]
    return x


def process_data():
    vocab_to_code, code_to_vocab = build_vocabulary()
    max_vocab_size = len(vocab_to_code)
    unknown = max_vocab_size - 1
    print('Final Vocab Size : ' + str(max_vocab_size))
    try:
        coded_dataset = []
        for i, review in enumerate(read_binary(FORMATTED_FILE_NAME)):
            coded_aspect = []
            coded_sentences = []

            if i == 0:
                print(review)

            sentences = review[1]
            aspect_words = review[0]
            polarities = review[2]

            for aspect_word in aspect_words:
                coded_aspect.append(vocab_to_code.get(aspect_word, unknown))

            for sent in sentences:
                coded_sentence = []
                tokens = NLP.tokenizer(sent[0])
                for token in tokens:
                    coded_sentence.append(vocab_to_code.get(token.orth_, unknown))
                coded_sentences.append(coded_sentence)

            coded_review = [coded_aspect, coded_sentences, polarities]

            # dataset
            coded_dataset.append(coded_review)
            write_binary(coded_dataset, PROCESSED_FILE_NAME)
            print('dump at {}'.format(i))

        datapoint = coded_dataset[0]
        print(datapoint)
        print(get_uncoded_data(code_to_vocab, datapoint))
    except KeyboardInterrupt:
        pass

# %%
process_data()
# Out:
# building vocabulary
# frequency distribution loaded
# loading embeddings
# loading ovv fastext model..
# Vocab count : 3952
# Final Vocab Size : 3954
# [['restaurant', 'general'], [['Judging from previous posts this used to be a good place, but not any longer.'], ['We, there were four of us, arrived at noon - the place was empty - and the staff acted like we were imposing on them and they were very rude.'], ['They never brought us complimentary noodles, ignored repeated requests for sugar, and threw our dishes on the table.'], ['The food was lousy - too sweet or too salty and the portions tiny.'], ['After all that, they complained to me about the small tip.'], ['Avoid this place!']], [1, 3, 3, 3, 3, 1]]
# dump at 0
# dump at 1
# dump at 2
# dump at 3
# dump at 4
# dump at 5
# dump at 6
# dump at 7
# dump at 8
# dump at 9
# dump at 10
# dump at 11
# dump at 12
# dump at 13
# dump at 14
# dump at 15
# dump at 16
# dump at 17
# dump at 18
# dump at 19
# dump at 20
# dump at 21
# dump at 22
# dump at 23
# dump at 24
# dump at 25
# dump at 26
# dump at 27
# dump at 28
# dump at 29
# dump at 30
# dump at 31
# dump at 32
# dump at 33
# dump at 34
# dump at 35
# dump at 36
# dump at 37
# dump at 38
# dump at 39
# dump at 40
# dump at 41
# dump at 42
# dump at 43
# dump at 44
# dump at 45
# dump at 46
# dump at 47
# dump at 48
# dump at 49
# dump at 50
# dump at 51
# dump at 52
# dump at 53
# dump at 54
# dump at 55
# dump at 56
# dump at 57
# dump at 58
# dump at 59
# dump at 60
# dump at 61
# dump at 62
# dump at 63
# dump at 64
# dump at 65
# dump at 66
# dump at 67
# dump at 68
# dump at 69
# dump at 70
# dump at 71
# dump at 72
# dump at 73
# dump at 74
# dump at 75
# dump at 76
# dump at 77
# dump at 78
# dump at 79
# dump at 80
# dump at 81
# dump at 82
# dump at 83
# dump at 84
# dump at 85
# dump at 86
# dump at 87
# dump at 88
# dump at 89
# dump at 90
# dump at 91
# dump at 92
# dump at 93
# dump at 94
# dump at 95
# dump at 96
# dump at 97
# dump at 98
# dump at 99
# dump at 100
# dump at 101
# dump at 102
# dump at 103
# dump at 104
# dump at 105
# dump at 106
# dump at 107
# dump at 108
# dump at 109
# dump at 110
# dump at 111
# dump at 112
# dump at 113
# dump at 114
# dump at 115
# dump at 116
# dump at 117
# dump at 118
# dump at 119
# dump at 120
# dump at 121
# dump at 122
# dump at 123
# dump at 124
# dump at 125
# dump at 126
# dump at 127
# dump at 128
# dump at 129
# dump at 130
# dump at 131
# dump at 132
# dump at 133
# dump at 134
# dump at 135
# dump at 136
# dump at 137
# dump at 138
# dump at 139
# dump at 140
# dump at 141
# dump at 142
# dump at 143
# dump at 144
# dump at 145
# dump at 146
# dump at 147
# dump at 148
# dump at 149
# dump at 150
# dump at 151
# dump at 152
# dump at 153
# dump at 154
# dump at 155
# dump at 156
# dump at 157
# dump at 158
# dump at 159
# dump at 160
# dump at 161
# dump at 162
# dump at 163
# dump at 164
# dump at 165
# dump at 166
# dump at 167
# dump at 168
# dump at 169
# dump at 170
# dump at 171
# dump at 172
# dump at 173
# dump at 174
# dump at 175
# dump at 176
# dump at 177
# dump at 178
# dump at 179
# dump at 180
# dump at 181
# dump at 182
# dump at 183
# dump at 184
# dump at 185
# dump at 186
# dump at 187
# dump at 188
# dump at 189
# dump at 190
# dump at 191
# dump at 192
# dump at 193
# dump at 194
# dump at 195
# dump at 196
# dump at 197
# dump at 198
# dump at 199
# dump at 200
# dump at 201
# dump at 202
# dump at 203
# dump at 204
# dump at 205
# dump at 206
# dump at 207
# dump at 208
# dump at 209
# dump at 210
# dump at 211
# dump at 212
# dump at 213
# dump at 214
# dump at 215
# dump at 216
# dump at 217
# dump at 218
# dump at 219
# dump at 220
# dump at 221
# dump at 222
# dump at 223
# dump at 224
# dump at 225
# dump at 226
# dump at 227
# dump at 228
# dump at 229
# dump at 230
# dump at 231
# dump at 232
# dump at 233
# dump at 234
# dump at 235
# dump at 236
# dump at 237
# dump at 238
# dump at 239
# dump at 240
# dump at 241
# dump at 242
# dump at 243
# dump at 244
# dump at 245
# dump at 246
# dump at 247
# dump at 248
# dump at 249
# dump at 250
# dump at 251
# dump at 252
# dump at 253
# dump at 254
# dump at 255
# dump at 256
# dump at 257
# dump at 258
# dump at 259
# dump at 260
# dump at 261
# dump at 262
# dump at 263
# dump at 264
# dump at 265
# dump at 266
# dump at 267
# dump at 268
# dump at 269
# dump at 270
# dump at 271
# dump at 272
# dump at 273
# dump at 274
# dump at 275
# dump at 276
# dump at 277
# dump at 278
# dump at 279
# dump at 280
# dump at 281
# dump at 282
# dump at 283
# dump at 284
# dump at 285
# dump at 286
# dump at 287
# dump at 288
# dump at 289
# dump at 290
# dump at 291
# dump at 292
# dump at 293
# dump at 294
# dump at 295
# dump at 296
# dump at 297
# dump at 298
# dump at 299
# dump at 300
# dump at 301
# dump at 302
# dump at 303
# dump at 304
# dump at 305
# dump at 306
# dump at 307
# dump at 308
# dump at 309
# dump at 310
# dump at 311
# dump at 312
# dump at 313
# dump at 314
# dump at 315
# dump at 316
# dump at 317
# dump at 318
# dump at 319
# dump at 320
# dump at 321
# dump at 322
# dump at 323
# dump at 324
# dump at 325
# dump at 326
# dump at 327
# dump at 328
# dump at 329
# dump at 330
# dump at 331
# dump at 332
# dump at 333
# dump at 334
# dump at 335
# dump at 336
# dump at 337
# dump at 338
# dump at 339
# dump at 340
# dump at 341
# dump at 342
# dump at 343
# dump at 344
# dump at 345
# dump at 346
# dump at 347
# dump at 348
# dump at 349
# dump at 350
# dump at 351
# dump at 352
# dump at 353
# dump at 354
# dump at 355
# dump at 356
# dump at 357
# dump at 358
# dump at 359
# dump at 360
# dump at 361
# dump at 362
# dump at 363
# dump at 364
# dump at 365
# dump at 366
# dump at 367
# dump at 368
# dump at 369
# dump at 370
# dump at 371
# dump at 372
# dump at 373
# dump at 374
# dump at 375
# dump at 376
# dump at 377
# dump at 378
# dump at 379
# dump at 380
# dump at 381
# dump at 382
# dump at 383
# dump at 384
# dump at 385
# dump at 386
# dump at 387
# dump at 388
# dump at 389
# dump at 390
# dump at 391
# dump at 392
# dump at 393
# dump at 394
# dump at 395
# dump at 396
# dump at 397
# dump at 398
# dump at 399
# dump at 400
# dump at 401
# dump at 402
# dump at 403
# dump at 404
# dump at 405
# dump at 406
# dump at 407
# dump at 408
# dump at 409
# dump at 410
# dump at 411
# dump at 412
# dump at 413
# dump at 414
# dump at 415
# dump at 416
# dump at 417
# dump at 418
# dump at 419
# dump at 420
# dump at 421
# dump at 422
# dump at 423
# dump at 424
# dump at 425
# dump at 426
# dump at 427
# dump at 428
# dump at 429
# dump at 430
# dump at 431
# dump at 432
# dump at 433
# dump at 434
# dump at 435
# dump at 436
# dump at 437
# dump at 438
# dump at 439
# dump at 440
# dump at 441
# dump at 442
# dump at 443
# dump at 444
# dump at 445
# dump at 446
# dump at 447
# dump at 448
# dump at 449
# dump at 450
# dump at 451
# dump at 452
# dump at 453
# dump at 454
# dump at 455
# dump at 456
# dump at 457
# dump at 458
# dump at 459
# dump at 460
# dump at 461
# dump at 462
# dump at 463
# dump at 464
# dump at 465
# dump at 466
# dump at 467
# dump at 468
# dump at 469
# dump at 470
# dump at 471
# dump at 472
# dump at 473
# dump at 474
# dump at 475
# dump at 476
# dump at 477
# dump at 478
# dump at 479
# dump at 480
# dump at 481
# dump at 482
# dump at 483
# dump at 484
# dump at 485
# dump at 486
# dump at 487
# dump at 488
# dump at 489
# dump at 490
# dump at 491
# dump at 492
# dump at 493
# dump at 494
# dump at 495
# dump at 496
# dump at 497
# dump at 498
# dump at 499
# dump at 500
# dump at 501
# dump at 502
# dump at 503
# dump at 504
# dump at 505
# dump at 506
# dump at 507
# dump at 508
# dump at 509
# dump at 510
# dump at 511
# dump at 512
# dump at 513
# dump at 514
# dump at 515
# dump at 516
# dump at 517
# dump at 518
# dump at 519
# dump at 520
# dump at 521
# dump at 522
# dump at 523
# dump at 524
# dump at 525
# dump at 526
# dump at 527
# dump at 528
# dump at 529
# dump at 530
# dump at 531
# dump at 532
# dump at 533
# dump at 534
# dump at 535
# dump at 536
# dump at 537
# dump at 538
# dump at 539
# dump at 540
# dump at 541
# dump at 542
# dump at 543
# dump at 544
# dump at 545
# dump at 546
# dump at 547
# dump at 548
# dump at 549
# dump at 550
# dump at 551
# dump at 552
# dump at 553
# dump at 554
# dump at 555
# dump at 556
# dump at 557
# dump at 558
# dump at 559
# dump at 560
# dump at 561
# dump at 562
# dump at 563
# dump at 564
# dump at 565
# dump at 566
# dump at 567
# dump at 568
# dump at 569
# dump at 570
# dump at 571
# dump at 572
# dump at 573
# dump at 574
# dump at 575
# dump at 576
# dump at 577
# dump at 578
# dump at 579
# dump at 580
# dump at 581
# dump at 582
# dump at 583
# dump at 584
# dump at 585
# dump at 586
# dump at 587
# dump at 588
# dump at 589
# dump at 590
# dump at 591
# dump at 592
# dump at 593
# dump at 594
# dump at 595
# dump at 596
# dump at 597
# dump at 598
# dump at 599
# dump at 600
# dump at 601
# dump at 602
# dump at 603
# dump at 604
# dump at 605
# dump at 606
# dump at 607
# dump at 608
# dump at 609
# dump at 610
# dump at 611
# dump at 612
# dump at 613
# dump at 614
# dump at 615
# dump at 616
# dump at 617
# dump at 618
# dump at 619
# dump at 620
# dump at 621
# dump at 622
# dump at 623
# dump at 624
# dump at 625
# dump at 626
# dump at 627
# dump at 628
# dump at 629
# dump at 630
# dump at 631
# dump at 632
# dump at 633
# dump at 634
# dump at 635
# dump at 636
# dump at 637
# dump at 638
# dump at 639
# dump at 640
# dump at 641
# dump at 642
# dump at 643
# dump at 644
# dump at 645
# dump at 646
# dump at 647
# dump at 648
# dump at 649
# dump at 650
# dump at 651
# dump at 652
# dump at 653
# dump at 654
# dump at 655
# dump at 656
# dump at 657
# dump at 658
# dump at 659
# dump at 660
# dump at 661
# dump at 662
# dump at 663
# dump at 664
# dump at 665
# dump at 666
# dump at 667
# dump at 668
# dump at 669
# dump at 670
# dump at 671
# dump at 672
# dump at 673
# dump at 674
# dump at 675
# dump at 676
# dump at 677
# dump at 678
# dump at 679
# dump at 680
# dump at 681
# dump at 682
# dump at 683
# dump at 684
# dump at 685
# dump at 686
# dump at 687
# dump at 688
# dump at 689
# dump at 690
# dump at 691
# dump at 692
# dump at 693
# dump at 694
# dump at 695
# dump at 696
# dump at 697
# dump at 698
# dump at 699
# dump at 700
# dump at 701
# dump at 702
# dump at 703
# dump at 704
# dump at 705
# dump at 706
# dump at 707
# dump at 708
# dump at 709
# dump at 710
# dump at 711
# dump at 712
# dump at 713
# dump at 714
# dump at 715
# dump at 716
# dump at 717
# dump at 718
# dump at 719
# dump at 720
# dump at 721
# dump at 722
# dump at 723
# dump at 724
# dump at 725
# dump at 726
# dump at 727
# dump at 728
# dump at 729
# dump at 730
# dump at 731
# dump at 732
# dump at 733
# dump at 734
# dump at 735
# dump at 736
# dump at 737
# dump at 738
# dump at 739
# dump at 740
# dump at 741
# dump at 742
# dump at 743
# dump at 744
# dump at 745
# dump at 746
# dump at 747
# dump at 748
# dump at 749
# dump at 750
# dump at 751
# dump at 752
# dump at 753
# dump at 754
# dump at 755
# dump at 756
# dump at 757
# dump at 758
# dump at 759
# dump at 760
# dump at 761
# dump at 762
# dump at 763
# dump at 764
# dump at 765
# dump at 766
# dump at 767
# dump at 768
# dump at 769
# dump at 770
# dump at 771
# dump at 772
# dump at 773
# dump at 774
# dump at 775
# dump at 776
# dump at 777
# dump at 778
# dump at 779
# dump at 780
# dump at 781
# dump at 782
# dump at 783
# dump at 784
# dump at 785
# dump at 786
# dump at 787
# dump at 788
# dump at 789
# dump at 790
# dump at 791
# dump at 792
# dump at 793
# dump at 794
# dump at 795
# dump at 796
# dump at 797
# dump at 798
# dump at 799
# dump at 800
# dump at 801
# dump at 802
# dump at 803
# dump at 804
# dump at 805
# dump at 806
# dump at 807
# dump at 808
# dump at 809
# dump at 810
# dump at 811
# dump at 812
# dump at 813
# dump at 814
# dump at 815
# dump at 816
# dump at 817
# dump at 818
# dump at 819
# dump at 820
# dump at 821
# dump at 822
# dump at 823
# dump at 824
# dump at 825
# dump at 826
# dump at 827
# dump at 828
# dump at 829
# dump at 830
# dump at 831
# dump at 832
# dump at 833
# dump at 834
# dump at 835
# dump at 836
# dump at 837
# dump at 838
# dump at 839
# dump at 840
# dump at 841
# dump at 842
# dump at 843
# dump at 844
# dump at 845
# dump at 846
# dump at 847
# dump at 848
# dump at 849
# dump at 850
# dump at 851
# dump at 852
# dump at 853
# dump at 854
# dump at 855
# dump at 856
# dump at 857
# dump at 858
# dump at 859
# dump at 860
# dump at 861
# dump at 862
# dump at 863
# dump at 864
# dump at 865
# dump at 866
# dump at 867
# dump at 868
# dump at 869
# dump at 870
# dump at 871
# dump at 872
# dump at 873
# dump at 874
# dump at 875
# dump at 876
# dump at 877
# dump at 878
# dump at 879
# dump at 880
# dump at 881
# dump at 882
# dump at 883
# dump at 884
# dump at 885
# dump at 886
# dump at 887
# dump at 888
# dump at 889
# dump at 890
# dump at 891
# dump at 892
# dump at 893
# dump at 894
# dump at 895
# dump at 896
# dump at 897
# dump at 898
# dump at 899
# dump at 900
# dump at 901
# dump at 902
# dump at 903
# dump at 904
# dump at 905
# dump at 906
# dump at 907
# dump at 908
# dump at 909
# dump at 910
# dump at 911
# dump at 912
# dump at 913
# dump at 914
# dump at 915
# dump at 916
# dump at 917
# dump at 918
# dump at 919
# dump at 920
# dump at 921
# dump at 922
# dump at 923
# dump at 924
# dump at 925
# dump at 926
# dump at 927
# dump at 928
# dump at 929
# dump at 930
# dump at 931
# dump at 932
# dump at 933
# dump at 934
# dump at 935
# dump at 936
# dump at 937
# dump at 938
# dump at 939
# dump at 940
# dump at 941
# dump at 942
# dump at 943
# dump at 944
# dump at 945
# dump at 946
# dump at 947
# dump at 948
# dump at 949
# dump at 950
# dump at 951
# dump at 952
# dump at 953
# dump at 954
# dump at 955
# dump at 956
# dump at 957
# dump at 958
# dump at 959
# dump at 960
# dump at 961
# dump at 962
# dump at 963
# dump at 964
# dump at 965
# dump at 966
# dump at 967
# dump at 968
# dump at 969
# dump at 970
# dump at 971
# dump at 972
# dump at 973
# dump at 974
# dump at 975
# dump at 976
# dump at 977
# dump at 978
# dump at 979
# dump at 980
# dump at 981
# dump at 982
# dump at 983
# dump at 984
# dump at 985
# dump at 986
# dump at 987
# dump at 988
# dump at 989
# dump at 990
# dump at 991
# dump at 992
# dump at 993
# dump at 994
# dump at 995
# dump at 996
# dump at 997
# dump at 998
# dump at 999
# dump at 1000
# dump at 1001
# dump at 1002
# dump at 1003
# dump at 1004
# dump at 1005
# dump at 1006
# dump at 1007
# dump at 1008
# dump at 1009
# dump at 1010
# dump at 1011
# dump at 1012
# dump at 1013
# dump at 1014
# dump at 1015
# dump at 1016
# dump at 1017
# dump at 1018
# dump at 1019
# dump at 1020
# dump at 1021
# dump at 1022
# dump at 1023
# dump at 1024
# dump at 1025
# dump at 1026
# dump at 1027
# dump at 1028
# dump at 1029
# dump at 1030
# dump at 1031
# dump at 1032
# dump at 1033
# dump at 1034
# dump at 1035
# dump at 1036
# dump at 1037
# dump at 1038
# dump at 1039
# dump at 1040
# dump at 1041
# dump at 1042
# dump at 1043
# dump at 1044
# dump at 1045
# dump at 1046
# dump at 1047
# dump at 1048
# dump at 1049
# dump at 1050
# dump at 1051
# dump at 1052
# dump at 1053
# dump at 1054
# dump at 1055
# dump at 1056
# dump at 1057
# dump at 1058
# dump at 1059
# dump at 1060
# dump at 1061
# dump at 1062
# dump at 1063
# dump at 1064
# dump at 1065
# dump at 1066
# dump at 1067
# dump at 1068
# dump at 1069
# dump at 1070
# dump at 1071
# dump at 1072
# dump at 1073
# dump at 1074
# dump at 1075
# dump at 1076
# dump at 1077
# dump at 1078
# dump at 1079
# dump at 1080
# dump at 1081
# dump at 1082
# dump at 1083
# dump at 1084
# dump at 1085
# dump at 1086
# dump at 1087
# dump at 1088
# dump at 1089
# dump at 1090
# dump at 1091
# dump at 1092
# dump at 1093
# dump at 1094
# dump at 1095
# dump at 1096
# dump at 1097
# dump at 1098
# dump at 1099
# dump at 1100
# dump at 1101
# dump at 1102
# dump at 1103
# dump at 1104
# dump at 1105
# dump at 1106
# dump at 1107
# dump at 1108
# dump at 1109
# dump at 1110
# dump at 1111
# dump at 1112
# dump at 1113
# dump at 1114
# dump at 1115
# dump at 1116
# dump at 1117
# dump at 1118
# dump at 1119
# dump at 1120
# dump at 1121
# dump at 1122
# dump at 1123
# dump at 1124
# dump at 1125
# dump at 1126
# dump at 1127
# dump at 1128
# dump at 1129
# dump at 1130
# dump at 1131
# dump at 1132
# dump at 1133
# dump at 1134
# dump at 1135
# dump at 1136
# dump at 1137
# dump at 1138
# dump at 1139
# dump at 1140
# dump at 1141
# dump at 1142
# dump at 1143
# dump at 1144
# dump at 1145
# dump at 1146
# dump at 1147
# dump at 1148
# dump at 1149
# dump at 1150
# dump at 1151
# dump at 1152
# dump at 1153
# dump at 1154
# dump at 1155
# dump at 1156
# dump at 1157
# dump at 1158
# dump at 1159
# dump at 1160
# dump at 1161
# dump at 1162
# dump at 1163
# dump at 1164
# dump at 1165
# dump at 1166
# dump at 1167
# dump at 1168
# dump at 1169
# dump at 1170
# dump at 1171
# dump at 1172
# dump at 1173
# dump at 1174
# dump at 1175
# dump at 1176
# dump at 1177
# dump at 1178
# dump at 1179
# dump at 1180
# dump at 1181
# dump at 1182
# dump at 1183
# dump at 1184
# dump at 1185
# dump at 1186
# dump at 1187
# dump at 1188
# dump at 1189
# dump at 1190
# dump at 1191
# dump at 1192
# dump at 1193
# dump at 1194
# dump at 1195
# dump at 1196
# dump at 1197
# dump at 1198
# dump at 1199
# dump at 1200
# dump at 1201
# dump at 1202
# dump at 1203
# dump at 1204
# dump at 1205
# dump at 1206
# dump at 1207
# dump at 1208
# dump at 1209
# dump at 1210
# dump at 1211
# dump at 1212
# dump at 1213
# dump at 1214
# dump at 1215
# dump at 1216
# dump at 1217
# dump at 1218
# dump at 1219
# dump at 1220
# dump at 1221
# dump at 1222
# dump at 1223
# dump at 1224
# dump at 1225
# dump at 1226
# dump at 1227
# dump at 1228
# dump at 1229
# dump at 1230
# dump at 1231
# dump at 1232
# dump at 1233
# dump at 1234
# dump at 1235
# dump at 1236
# dump at 1237
# dump at 1238
# dump at 1239
# dump at 1240
# dump at 1241
# dump at 1242
# dump at 1243
# dump at 1244
# dump at 1245
# dump at 1246
# dump at 1247
# dump at 1248
# dump at 1249
# dump at 1250
# dump at 1251
# dump at 1252
# dump at 1253
# dump at 1254
# dump at 1255
# dump at 1256
# dump at 1257
# dump at 1258
# dump at 1259
# dump at 1260
# dump at 1261
# dump at 1262
# dump at 1263
# dump at 1264
# dump at 1265
# dump at 1266
# dump at 1267
# dump at 1268
# dump at 1269
# dump at 1270
# dump at 1271
# dump at 1272
# dump at 1273
# dump at 1274
# dump at 1275
# dump at 1276
# dump at 1277
# dump at 1278
# dump at 1279
# dump at 1280
# dump at 1281
# dump at 1282
# dump at 1283
# dump at 1284
# dump at 1285
# dump at 1286
# dump at 1287
# dump at 1288
# dump at 1289
# dump at 1290
# dump at 1291
# dump at 1292
# dump at 1293
# dump at 1294
# dump at 1295
# dump at 1296
# dump at 1297
# dump at 1298
# dump at 1299
# dump at 1300
# dump at 1301
# dump at 1302
# dump at 1303
# dump at 1304
# dump at 1305
# dump at 1306
# dump at 1307
# dump at 1308
# dump at 1309
# dump at 1310
# dump at 1311
# dump at 1312
# dump at 1313
# dump at 1314
# dump at 1315
# dump at 1316
# dump at 1317
# dump at 1318
# dump at 1319
# dump at 1320
# dump at 1321
# dump at 1322
# dump at 1323
# dump at 1324
# dump at 1325
# dump at 1326
# dump at 1327
# dump at 1328
# dump at 1329
# dump at 1330
# dump at 1331
# dump at 1332
# dump at 1333
# dump at 1334
# dump at 1335
# dump at 1336
# dump at 1337
# dump at 1338
# dump at 1339
# dump at 1340
# dump at 1341
# dump at 1342
# dump at 1343
# dump at 1344
# dump at 1345
# dump at 1346
# dump at 1347
# dump at 1348
# dump at 1349
# dump at 1350
# dump at 1351
# dump at 1352
# dump at 1353
# dump at 1354
# dump at 1355
# dump at 1356
# dump at 1357
# dump at 1358
# dump at 1359
# dump at 1360
# dump at 1361
# dump at 1362
# dump at 1363
# dump at 1364
# dump at 1365
# dump at 1366
# dump at 1367
# dump at 1368
# dump at 1369
# dump at 1370
# dump at 1371
# dump at 1372
# dump at 1373
# dump at 1374
# dump at 1375
# dump at 1376
# dump at 1377
# dump at 1378
# dump at 1379
# dump at 1380
# dump at 1381
# dump at 1382
# dump at 1383
# dump at 1384
# dump at 1385
# dump at 1386
# dump at 1387
# dump at 1388
# dump at 1389
# dump at 1390
# dump at 1391
# dump at 1392
# dump at 1393
# dump at 1394
# dump at 1395
# dump at 1396
# dump at 1397
# dump at 1398
# dump at 1399
# dump at 1400
# dump at 1401
# dump at 1402
# dump at 1403
# dump at 1404
# dump at 1405
# dump at 1406
# dump at 1407
# dump at 1408
# dump at 1409
# dump at 1410
# dump at 1411
# dump at 1412
# dump at 1413
# dump at 1414
# dump at 1415
# dump at 1416
# dump at 1417
# dump at 1418
# dump at 1419
# dump at 1420
# dump at 1421
# dump at 1422
# dump at 1423
# dump at 1424
# dump at 1425
# dump at 1426
# dump at 1427
# dump at 1428
# dump at 1429
# dump at 1430
# dump at 1431
# dump at 1432
# dump at 1433
# dump at 1434
# dump at 1435
# dump at 1436
# dump at 1437
# dump at 1438
# dump at 1439
# dump at 1440
# dump at 1441
# dump at 1442
# dump at 1443
# dump at 1444
# dump at 1445
# dump at 1446
# dump at 1447
# dump at 1448
# dump at 1449
# dump at 1450
# dump at 1451
# dump at 1452
# dump at 1453
# dump at 1454
# dump at 1455
# dump at 1456
# dump at 1457
# dump at 1458
# dump at 1459
# dump at 1460
# dump at 1461
# dump at 1462
# dump at 1463
# dump at 1464
# dump at 1465
# dump at 1466
# dump at 1467
# dump at 1468
# dump at 1469
# dump at 1470
# dump at 1471
# dump at 1472
# dump at 1473
# dump at 1474
# dump at 1475
# dump at 1476
# dump at 1477
# dump at 1478
# dump at 1479
# dump at 1480
# dump at 1481
# dump at 1482
# dump at 1483
# dump at 1484
# dump at 1485
# dump at 1486
# dump at 1487
# dump at 1488
# dump at 1489
# dump at 1490
# dump at 1491
# dump at 1492
# dump at 1493
# dump at 1494
# dump at 1495
# dump at 1496
# dump at 1497
# dump at 1498
# dump at 1499
# dump at 1500
# dump at 1501
# dump at 1502
# dump at 1503
# dump at 1504
# dump at 1505
# dump at 1506
# dump at 1507
# dump at 1508
# dump at 1509
# dump at 1510
# dump at 1511
# dump at 1512
# dump at 1513
# dump at 1514
# dump at 1515
# dump at 1516
# dump at 1517
# dump at 1518
# dump at 1519
# dump at 1520
# dump at 1521
# dump at 1522
# dump at 1523
# dump at 1524
# dump at 1525
# dump at 1526
# dump at 1527
# dump at 1528
# dump at 1529
# dump at 1530
# dump at 1531
# dump at 1532
# dump at 1533
# dump at 1534
# dump at 1535
# dump at 1536
# dump at 1537
# dump at 1538
# dump at 1539
# dump at 1540
# dump at 1541
# dump at 1542
# dump at 1543
# dump at 1544
# dump at 1545
# dump at 1546
# dump at 1547
# dump at 1548
# dump at 1549
# dump at 1550
# dump at 1551
# dump at 1552
# dump at 1553
# dump at 1554
# dump at 1555
# dump at 1556
# dump at 1557
# dump at 1558
# dump at 1559
# dump at 1560
# dump at 1561
# dump at 1562
# dump at 1563
# dump at 1564
# dump at 1565
# dump at 1566
# dump at 1567
# dump at 1568
# dump at 1569
# dump at 1570
# dump at 1571
# dump at 1572
# dump at 1573
# dump at 1574
# dump at 1575
# dump at 1576
# dump at 1577
# dump at 1578
# dump at 1579
# dump at 1580
# dump at 1581
# dump at 1582
# dump at 1583
# dump at 1584
# dump at 1585
# dump at 1586
# dump at 1587
# dump at 1588
# dump at 1589
# dump at 1590
# dump at 1591
# dump at 1592
# dump at 1593
# dump at 1594
# dump at 1595
# dump at 1596
# dump at 1597
# dump at 1598
# dump at 1599
# dump at 1600
# dump at 1601
# dump at 1602
# dump at 1603
# dump at 1604
# dump at 1605
# dump at 1606
# dump at 1607
# dump at 1608
# dump at 1609
# dump at 1610
# dump at 1611
# dump at 1612
# dump at 1613
# dump at 1614
# dump at 1615
# dump at 1616
# dump at 1617
# dump at 1618
# dump at 1619
# dump at 1620
# dump at 1621
# dump at 1622
# dump at 1623
# dump at 1624
# dump at 1625
# dump at 1626
# dump at 1627
# dump at 1628
# dump at 1629
# dump at 1630
# dump at 1631
# dump at 1632
# dump at 1633
# dump at 1634
# dump at 1635
# dump at 1636
# dump at 1637
# dump at 1638
# dump at 1639
# dump at 1640
# dump at 1641
# dump at 1642
# dump at 1643
# dump at 1644
# dump at 1645
# dump at 1646
# dump at 1647
# dump at 1648
# dump at 1649
# dump at 1650
# dump at 1651
# dump at 1652
# dump at 1653
# dump at 1654
# dump at 1655
# dump at 1656
# dump at 1657
# dump at 1658
# dump at 1659
# dump at 1660
# dump at 1661
# dump at 1662
# dump at 1663
# dump at 1664
# dump at 1665
# dump at 1666
# dump at 1667
# dump at 1668
# dump at 1669
# dump at 1670
# dump at 1671
# dump at 1672
# dump at 1673
# dump at 1674
# dump at 1675
# dump at 1676
# dump at 1677
# dump at 1678
# dump at 1679
# dump at 1680
# dump at 1681
# dump at 1682
# dump at 1683
# dump at 1684
# dump at 1685
# dump at 1686
# dump at 1687
# dump at 1688
# dump at 1689
# dump at 1690
# dump at 1691
# dump at 1692
# dump at 1693
# dump at 1694
# dump at 1695
# dump at 1696
# dump at 1697
# dump at 1698
# dump at 1699
# dump at 1700
# dump at 1701
# dump at 1702
# dump at 1703
# dump at 1704
# dump at 1705
# dump at 1706
# dump at 1707
# dump at 1708
# dump at 1709
# dump at 1710
# dump at 1711
# dump at 1712
# dump at 1713
# dump at 1714
# dump at 1715
# dump at 1716
# dump at 1717
# dump at 1718
# dump at 1719
# dump at 1720
# dump at 1721
# dump at 1722
# dump at 1723
# dump at 1724
# dump at 1725
# dump at 1726
# dump at 1727
# dump at 1728
# dump at 1729
# dump at 1730
# dump at 1731
# dump at 1732
# dump at 1733
# dump at 1734
# dump at 1735
# dump at 1736
# dump at 1737
# dump at 1738
# dump at 1739
# dump at 1740
# dump at 1741
# dump at 1742
# dump at 1743
# dump at 1744
# dump at 1745
# dump at 1746
# dump at 1747
# dump at 1748
# dump at 1749
# dump at 1750
# dump at 1751
# dump at 1752
# dump at 1753
# dump at 1754
# dump at 1755
# dump at 1756
# dump at 1757
# dump at 1758
# dump at 1759
# dump at 1760
# dump at 1761
# dump at 1762
# dump at 1763
# dump at 1764
# dump at 1765
# dump at 1766
# dump at 1767
# dump at 1768
# dump at 1769
# dump at 1770
# dump at 1771
# dump at 1772
# dump at 1773
# dump at 1774
# dump at 1775
# dump at 1776
# dump at 1777
# dump at 1778
# dump at 1779
# dump at 1780
# dump at 1781
# dump at 1782
# dump at 1783
# dump at 1784
# dump at 1785
# dump at 1786
# dump at 1787
# dump at 1788
# dump at 1789
# dump at 1790
# dump at 1791
# dump at 1792
# dump at 1793
# dump at 1794
# dump at 1795
# dump at 1796
# dump at 1797
# dump at 1798
# dump at 1799
# dump at 1800
# dump at 1801
# dump at 1802
# dump at 1803
# dump at 1804
# dump at 1805
# dump at 1806
# dump at 1807
# dump at 1808
# dump at 1809
# dump at 1810
# dump at 1811
# dump at 1812
# dump at 1813
# dump at 1814
# dump at 1815
# dump at 1816
# dump at 1817
# dump at 1818
# dump at 1819
# dump at 1820
# dump at 1821
# dump at 1822
# dump at 1823
# dump at 1824
# dump at 1825
# dump at 1826
# dump at 1827
# dump at 1828
# dump at 1829
# dump at 1830
# dump at 1831
# dump at 1832
# dump at 1833
# dump at 1834
# dump at 1835
# dump at 1836
# dump at 1837
# dump at 1838
# dump at 1839
# dump at 1840
# dump at 1841
# dump at 1842
# dump at 1843
# dump at 1844
# dump at 1845
# dump at 1846
# dump at 1847
# dump at 1848
# dump at 1849
# dump at 1850
# dump at 1851
# dump at 1852
# dump at 1853
# dump at 1854
# dump at 1855
# dump at 1856
# dump at 1857
# dump at 1858
# dump at 1859
# dump at 1860
# dump at 1861
# dump at 1862
# dump at 1863
# dump at 1864
# dump at 1865
# dump at 1866
# dump at 1867
# dump at 1868
# dump at 1869
# dump at 1870
# dump at 1871
# dump at 1872
# dump at 1873
# dump at 1874
# dump at 1875
# dump at 1876
# dump at 1877
# dump at 1878
# dump at 1879
# dump at 1880
# dump at 1881
# dump at 1882
# dump at 1883
# dump at 1884
# dump at 1885
# dump at 1886
# dump at 1887
# dump at 1888
# dump at 1889
# dump at 1890
# dump at 1891
# dump at 1892
# dump at 1893
# dump at 1894
# dump at 1895
# dump at 1896
# dump at 1897
# dump at 1898
# dump at 1899
# dump at 1900
# dump at 1901
# dump at 1902
# dump at 1903
# dump at 1904
# dump at 1905
# dump at 1906
# dump at 1907
# dump at 1908
# dump at 1909
# dump at 1910
# dump at 1911
# dump at 1912
# dump at 1913
# dump at 1914
# dump at 1915
# dump at 1916
# dump at 1917
# dump at 1918
# dump at 1919
# dump at 1920
# dump at 1921
# dump at 1922
# dump at 1923
# dump at 1924
# dump at 1925
# dump at 1926
# dump at 1927
# dump at 1928
# dump at 1929
# dump at 1930
# dump at 1931
# dump at 1932
# dump at 1933
# dump at 1934
# dump at 1935
# dump at 1936
# dump at 1937
# dump at 1938
# dump at 1939
# dump at 1940
# dump at 1941
# dump at 1942
# dump at 1943
# dump at 1944
# dump at 1945
# dump at 1946
# dump at 1947
# dump at 1948
# dump at 1949
# dump at 1950
# dump at 1951
# dump at 1952
# dump at 1953
# dump at 1954
# dump at 1955
# dump at 1956
# dump at 1957
# dump at 1958
# dump at 1959
# dump at 1960
# dump at 1961
# dump at 1962
# dump at 1963
# dump at 1964
# dump at 1965
# dump at 1966
# dump at 1967
# dump at 1968
# dump at 1969
# dump at 1970
# dump at 1971
# dump at 1972
# dump at 1973
# dump at 1974
# dump at 1975
# dump at 1976
# dump at 1977
# dump at 1978
# dump at 1979
# dump at 1980
# dump at 1981
# dump at 1982
# dump at 1983
# dump at 1984
# dump at 1985
# dump at 1986
# dump at 1987
# dump at 1988
# dump at 1989
# dump at 1990
# dump at 1991
# dump at 1992
# dump at 1993
# dump at 1994
# dump at 1995
# dump at 1996
# dump at 1997
# dump at 1998
# dump at 1999
# dump at 2000
# dump at 2001
# dump at 2002
# dump at 2003
# dump at 2004
# dump at 2005
# dump at 2006
# dump at 2007
# dump at 2008
# dump at 2009
# dump at 2010
# dump at 2011
# dump at 2012
# dump at 2013
# dump at 2014
# dump at 2015
# dump at 2016
# dump at 2017
# dump at 2018
# dump at 2019
# dump at 2020
# dump at 2021
# dump at 2022
# dump at 2023
# dump at 2024
# dump at 2025
# dump at 2026
# dump at 2027
# dump at 2028
# dump at 2029
# dump at 2030
# dump at 2031
# dump at 2032
# dump at 2033
# dump at 2034
# dump at 2035
# dump at 2036
# dump at 2037
# dump at 2038
# dump at 2039
# dump at 2040
# dump at 2041
# dump at 2042
# dump at 2043
# dump at 2044
# dump at 2045
# dump at 2046
# dump at 2047
# dump at 2048
# dump at 2049
# dump at 2050
# dump at 2051
# dump at 2052
# dump at 2053
# dump at 2054
# dump at 2055
# dump at 2056
# dump at 2057
# dump at 2058
# dump at 2059
# dump at 2060
# dump at 2061
# dump at 2062
# dump at 2063
# dump at 2064
# dump at 2065
# dump at 2066
# dump at 2067
# dump at 2068
# dump at 2069
# dump at 2070
# dump at 2071
# dump at 2072
# dump at 2073
# dump at 2074
# dump at 2075
# dump at 2076
# dump at 2077
# dump at 2078
# dump at 2079
# dump at 2080
# dump at 2081
# dump at 2082
# dump at 2083
# dump at 2084
# dump at 2085
# dump at 2086
# dump at 2087
# dump at 2088
# dump at 2089
# dump at 2090
# dump at 2091
# dump at 2092
# dump at 2093
# dump at 2094
# dump at 2095
# dump at 2096
# dump at 2097
# dump at 2098
# dump at 2099
# dump at 2100
# dump at 2101
# dump at 2102
# dump at 2103
# dump at 2104
# dump at 2105
# dump at 2106
# dump at 2107
# dump at 2108
# dump at 2109
# dump at 2110
# dump at 2111
# dump at 2112
# dump at 2113
# dump at 2114
# dump at 2115
# dump at 2116
# dump at 2117
# dump at 2118
# dump at 2119
# dump at 2120
# dump at 2121
# dump at 2122
# dump at 2123
# dump at 2124
# dump at 2125
# dump at 2126
# dump at 2127
# dump at 2128
# dump at 2129
# dump at 2130
# dump at 2131
# dump at 2132
# dump at 2133
# dump at 2134
# dump at 2135
# dump at 2136
# dump at 2137
# dump at 2138
# dump at 2139
# dump at 2140
# dump at 2141
# dump at 2142
# dump at 2143
# dump at 2144
# dump at 2145
# dump at 2146
# dump at 2147
# dump at 2148
# dump at 2149
# dump at 2150
# dump at 2151
# dump at 2152
# dump at 2153
# dump at 2154
# dump at 2155
# dump at 2156
# dump at 2157
# dump at 2158
# dump at 2159
# dump at 2160
# dump at 2161
# dump at 2162
# dump at 2163
# dump at 2164
# dump at 2165
# dump at 2166
# dump at 2167
# dump at 2168
# dump at 2169
# dump at 2170
# dump at 2171
# dump at 2172
# dump at 2173
# dump at 2174
# dump at 2175
# dump at 2176
# dump at 2177
# dump at 2178
# dump at 2179
# dump at 2180
# dump at 2181
# dump at 2182
# dump at 2183
# dump at 2184
# dump at 2185
# dump at 2186
# dump at 2187
# dump at 2188
# dump at 2189
# dump at 2190
# dump at 2191
# dump at 2192
# dump at 2193
# dump at 2194
# dump at 2195
# dump at 2196
# dump at 2197
# dump at 2198
# dump at 2199
# dump at 2200
# dump at 2201
# dump at 2202
# dump at 2203
# dump at 2204
# dump at 2205
# dump at 2206
# dump at 2207
# dump at 2208
# dump at 2209
# dump at 2210
# dump at 2211
# dump at 2212
# dump at 2213
# dump at 2214
# dump at 2215
# dump at 2216
# dump at 2217
# dump at 2218
# dump at 2219
# dump at 2220
# dump at 2221
# dump at 2222
# dump at 2223
# dump at 2224
# dump at 2225
# dump at 2226
# dump at 2227
# dump at 2228
# dump at 2229
# dump at 2230
# dump at 2231
# dump at 2232
# dump at 2233
# dump at 2234
# dump at 2235
# dump at 2236
# dump at 2237
# dump at 2238
# dump at 2239
# dump at 2240
# dump at 2241
# dump at 2242
# dump at 2243
# dump at 2244
# dump at 2245
# dump at 2246
# dump at 2247
# dump at 2248
# dump at 2249
# dump at 2250
# dump at 2251
# dump at 2252
# dump at 2253
# dump at 2254
# dump at 2255
# dump at 2256
# dump at 2257
# dump at 2258
# dump at 2259
# dump at 2260
# dump at 2261
# dump at 2262
# dump at 2263
# dump at 2264
# dump at 2265
# dump at 2266
# dump at 2267
# dump at 2268
# dump at 2269
# dump at 2270
# dump at 2271
# dump at 2272
# dump at 2273
# dump at 2274
# dump at 2275
# dump at 2276
# dump at 2277
# dump at 2278
# dump at 2279
# dump at 2280
# dump at 2281
# dump at 2282
# dump at 2283
# dump at 2284
# dump at 2285
# dump at 2286
# dump at 2287
# dump at 2288
# dump at 2289
# dump at 2290
# dump at 2291
# dump at 2292
# dump at 2293
# dump at 2294
# dump at 2295
# dump at 2296
# dump at 2297
# dump at 2298
# dump at 2299
# dump at 2300
# dump at 2301
# dump at 2302
# dump at 2303
# dump at 2304
# dump at 2305
# dump at 2306
# dump at 2307
# dump at 2308
# dump at 2309
# dump at 2310
# dump at 2311
# dump at 2312
# dump at 2313
# dump at 2314
# dump at 2315
# dump at 2316
# dump at 2317
# dump at 2318
# dump at 2319
# dump at 2320
# dump at 2321
# dump at 2322
# dump at 2323
# dump at 2324
# dump at 2325
# dump at 2326
# dump at 2327
# dump at 2328
# dump at 2329
# dump at 2330
# dump at 2331
# dump at 2332
# dump at 2333
# dump at 2334
# dump at 2335
# dump at 2336
# dump at 2337
# dump at 2338
# dump at 2339
# dump at 2340
# dump at 2341
# dump at 2342
# dump at 2343
# dump at 2344
# dump at 2345
# dump at 2346
# dump at 2347
# dump at 2348
# dump at 2349
# dump at 2350
# dump at 2351
# dump at 2352
# dump at 2353
# dump at 2354
# dump at 2355
# dump at 2356
# dump at 2357
# dump at 2358
# dump at 2359
# dump at 2360
# dump at 2361
# dump at 2362
# dump at 2363
# dump at 2364
# dump at 2365
# dump at 2366
# dump at 2367
# dump at 2368
# dump at 2369
# dump at 2370
# dump at 2371
# dump at 2372
# dump at 2373
# dump at 2374
# dump at 2375
# dump at 2376
# dump at 2377
# dump at 2378
# dump at 2379
# dump at 2380
# dump at 2381
# dump at 2382
# dump at 2383
# dump at 2384
# dump at 2385
# dump at 2386
# dump at 2387
# dump at 2388
# dump at 2389
# dump at 2390
# dump at 2391
# dump at 2392
# dump at 2393
# dump at 2394
# dump at 2395
# dump at 2396
# dump at 2397
# dump at 2398
# dump at 2399
# dump at 2400
# dump at 2401
# dump at 2402
# dump at 2403
# dump at 2404
# dump at 2405
# dump at 2406
# dump at 2407
# dump at 2408
# dump at 2409
# dump at 2410
# dump at 2411
# dump at 2412
# dump at 2413
# dump at 2414
# dump at 2415
# dump at 2416
# dump at 2417
# dump at 2418
# dump at 2419
# dump at 2420
# dump at 2421
# dump at 2422
# dump at 2423
# dump at 2424
# dump at 2425
# dump at 2426
# dump at 2427
# dump at 2428
# dump at 2429
# dump at 2430
# dump at 2431
# dump at 2432
# dump at 2433
# dump at 2434
# dump at 2435
# dump at 2436
# dump at 2437
# dump at 2438
# dump at 2439
# dump at 2440
# dump at 2441
# dump at 2442
# dump at 2443
# dump at 2444
# dump at 2445
# dump at 2446
# dump at 2447
# dump at 2448
# dump at 2449
# dump at 2450
# dump at 2451
# dump at 2452
# dump at 2453
# dump at 2454
# dump at 2455
# dump at 2456
# dump at 2457
# dump at 2458
# dump at 2459
# dump at 2460
# dump at 2461
# dump at 2462
# dump at 2463
# dump at 2464
# dump at 2465
# dump at 2466
# dump at 2467
# dump at 2468
# dump at 2469
# dump at 2470
# dump at 2471
# dump at 2472
# dump at 2473
# dump at 2474
# dump at 2475
# dump at 2476
# dump at 2477
# dump at 2478
# dump at 2479
# dump at 2480
# dump at 2481
# dump at 2482
# dump at 2483
# dump at 2484
# dump at 2485
# dump at 2486
# dump at 2487
# dump at 2488
# dump at 2489
# dump at 2490
# dump at 2491
# dump at 2492
# dump at 2493
# dump at 2494
# dump at 2495
# dump at 2496
# dump at 2497
# dump at 2498
# dump at 2499
# dump at 2500
# dump at 2501
# dump at 2502
# dump at 2503
# dump at 2504
# dump at 2505
# dump at 2506
# dump at 2507
# dump at 2508
# dump at 2509
# dump at 2510
# dump at 2511
# dump at 2512
# dump at 2513
# dump at 2514
# dump at 2515
# dump at 2516
# dump at 2517
# dump at 2518
# dump at 2519
# dump at 2520
# dump at 2521
# dump at 2522
# dump at 2523
# dump at 2524
# dump at 2525
# dump at 2526
# dump at 2527
# dump at 2528
# dump at 2529
# dump at 2530
# dump at 2531
# dump at 2532
# dump at 2533
# dump at 2534
# dump at 2535
# dump at 2536
# dump at 2537
# dump at 2538
# dump at 2539
# dump at 2540
# dump at 2541
# dump at 2542
# dump at 2543
# dump at 2544
# dump at 2545
# dump at 2546
# dump at 2547
# dump at 2548
# dump at 2549
# dump at 2550
# dump at 2551
# dump at 2552
# dump at 2553
# dump at 2554
# dump at 2555
# dump at 2556
# dump at 2557
# dump at 2558
# dump at 2559
# dump at 2560
# dump at 2561
# dump at 2562
# dump at 2563
# dump at 2564
# dump at 2565
# dump at 2566
# dump at 2567
# dump at 2568
# dump at 2569
# dump at 2570
# dump at 2571
# dump at 2572
# dump at 2573
# dump at 2574
# dump at 2575
# dump at 2576
# dump at 2577
# dump at 2578
# dump at 2579
# dump at 2580
# dump at 2581
# dump at 2582
# dump at 2583
# dump at 2584
# dump at 2585
# dump at 2586
# dump at 2587
# dump at 2588
# dump at 2589
# dump at 2590
# dump at 2591
# dump at 2592
# dump at 2593
# dump at 2594
# dump at 2595
# dump at 2596
# dump at 2597
# dump at 2598
# dump at 2599
# dump at 2600
# dump at 2601
# dump at 2602
# dump at 2603
# dump at 2604
# dump at 2605
# dump at 2606
# dump at 2607
# dump at 2608
# dump at 2609
# dump at 2610
# dump at 2611
# dump at 2612
# dump at 2613
# dump at 2614
# dump at 2615
# dump at 2616
# dump at 2617
# dump at 2618
# dump at 2619
# dump at 2620
# dump at 2621
# dump at 2622
# dump at 2623
# dump at 2624
# dump at 2625
# dump at 2626
# dump at 2627
# dump at 2628
# dump at 2629
# dump at 2630
# dump at 2631
# dump at 2632
# dump at 2633
# dump at 2634
# dump at 2635
# dump at 2636
# dump at 2637
# dump at 2638
# dump at 2639
# dump at 2640
# dump at 2641
# dump at 2642
# dump at 2643
# dump at 2644
# dump at 2645
# dump at 2646
# dump at 2647
# dump at 2648
# dump at 2649
# dump at 2650
# dump at 2651
# dump at 2652
# dump at 2653
# dump at 2654
# dump at 2655
# dump at 2656
# dump at 2657
# dump at 2658
# dump at 2659
# dump at 2660
# dump at 2661
# dump at 2662
# dump at 2663
# dump at 2664
# dump at 2665
# dump at 2666
# dump at 2667
# dump at 2668
# dump at 2669
# dump at 2670
# dump at 2671
# dump at 2672
# dump at 2673
# dump at 2674
# dump at 2675
# dump at 2676
# dump at 2677
# dump at 2678
# dump at 2679
# dump at 2680
# dump at 2681
# dump at 2682
# dump at 2683
# dump at 2684
# dump at 2685
# dump at 2686
# dump at 2687
# dump at 2688
# dump at 2689
# dump at 2690
# dump at 2691
# dump at 2692
# dump at 2693
# dump at 2694
# dump at 2695
# dump at 2696
# dump at 2697
# dump at 2698
# dump at 2699
# dump at 2700
# dump at 2701
# dump at 2702
# dump at 2703
# dump at 2704
# dump at 2705
# dump at 2706
# dump at 2707
# dump at 2708
# dump at 2709
# dump at 2710
# dump at 2711
# dump at 2712
# dump at 2713
# dump at 2714
# dump at 2715
# dump at 2716
# dump at 2717
# dump at 2718
# dump at 2719
# dump at 2720
# dump at 2721
# dump at 2722
# dump at 2723
# dump at 2724
# dump at 2725
# dump at 2726
# dump at 2727
# dump at 2728
# dump at 2729
# dump at 2730
# dump at 2731
# dump at 2732
# dump at 2733
# dump at 2734
# dump at 2735
# dump at 2736
# dump at 2737
# dump at 2738
# dump at 2739
# dump at 2740
# dump at 2741
# dump at 2742
# dump at 2743
# dump at 2744
# dump at 2745
# dump at 2746
# dump at 2747
# dump at 2748
# dump at 2749
# dump at 2750
# dump at 2751
# dump at 2752
# dump at 2753
# dump at 2754
# dump at 2755
# dump at 2756
# dump at 2757
# dump at 2758
# dump at 2759
# dump at 2760
# dump at 2761
# dump at 2762
# dump at 2763
# dump at 2764
# dump at 2765
# dump at 2766
# dump at 2767
# dump at 2768
# dump at 2769
# dump at 2770
# dump at 2771
# dump at 2772
# dump at 2773
# dump at 2774
# dump at 2775
# dump at 2776
# dump at 2777
# dump at 2778
# dump at 2779
# dump at 2780
# dump at 2781
# dump at 2782
# dump at 2783
# dump at 2784
# dump at 2785
# dump at 2786
# dump at 2787
# dump at 2788
# dump at 2789
# dump at 2790
# dump at 2791
# dump at 2792
# dump at 2793
# dump at 2794
# dump at 2795
# dump at 2796
# dump at 2797
# dump at 2798
# dump at 2799
# dump at 2800
# dump at 2801
# dump at 2802
# dump at 2803
# dump at 2804
# dump at 2805
# dump at 2806
# dump at 2807
# dump at 2808
# dump at 2809
# dump at 2810
# dump at 2811
# dump at 2812
# dump at 2813
# dump at 2814
# dump at 2815
# dump at 2816
# dump at 2817
# dump at 2818
# dump at 2819
# dump at 2820
# dump at 2821
# dump at 2822
# dump at 2823
# dump at 2824
# dump at 2825
# dump at 2826
# dump at 2827
# dump at 2828
# dump at 2829
# dump at 2830
# dump at 2831
# dump at 2832
# dump at 2833
# dump at 2834
# dump at 2835
# dump at 2836
# dump at 2837
# dump at 2838
# dump at 2839
# dump at 2840
# dump at 2841
# dump at 2842
# dump at 2843
# dump at 2844
# dump at 2845
# dump at 2846
# dump at 2847
# dump at 2848
# dump at 2849
# dump at 2850
# dump at 2851
# dump at 2852
# dump at 2853
# dump at 2854
# dump at 2855
# dump at 2856
# dump at 2857
# dump at 2858
# dump at 2859
# dump at 2860
# dump at 2861
# dump at 2862
# dump at 2863
# dump at 2864
# dump at 2865
# dump at 2866
# dump at 2867
# dump at 2868
# dump at 2869
# dump at 2870
# dump at 2871
# dump at 2872
# dump at 2873
# dump at 2874
# dump at 2875
# dump at 2876
# dump at 2877
# dump at 2878
# dump at 2879
# dump at 2880
# dump at 2881
# dump at 2882
# dump at 2883
# dump at 2884
# dump at 2885
# dump at 2886
# dump at 2887
# dump at 2888
# dump at 2889
# dump at 2890
# dump at 2891
# dump at 2892
# dump at 2893
# dump at 2894
# dump at 2895
# dump at 2896
# dump at 2897
# dump at 2898
# dump at 2899
# dump at 2900
# dump at 2901
# dump at 2902
# dump at 2903
# dump at 2904
# dump at 2905
# dump at 2906
# dump at 2907
# dump at 2908
# dump at 2909
# dump at 2910
# dump at 2911
# dump at 2912
# dump at 2913
# dump at 2914
# dump at 2915
# dump at 2916
# dump at 2917
# dump at 2918
# dump at 2919
# dump at 2920
# dump at 2921
# dump at 2922
# dump at 2923
# dump at 2924
# dump at 2925
# dump at 2926
# dump at 2927
# dump at 2928
# dump at 2929
# dump at 2930
# dump at 2931
# dump at 2932
# dump at 2933
# dump at 2934
# dump at 2935
# dump at 2936
# dump at 2937
# dump at 2938
# dump at 2939
# dump at 2940
# dump at 2941
# dump at 2942
# dump at 2943
# dump at 2944
# dump at 2945
# dump at 2946
# dump at 2947
# dump at 2948
# dump at 2949
# dump at 2950
# dump at 2951
# dump at 2952
# dump at 2953
# dump at 2954
# dump at 2955
# dump at 2956
# dump at 2957
# dump at 2958
# dump at 2959
# dump at 2960
# dump at 2961
# dump at 2962
# dump at 2963
# dump at 2964
# dump at 2965
# dump at 2966
# dump at 2967
# dump at 2968
# dump at 2969
# dump at 2970
# dump at 2971
# dump at 2972
# dump at 2973
# dump at 2974
# dump at 2975
# dump at 2976
# dump at 2977
# dump at 2978
# dump at 2979
# dump at 2980
# dump at 2981
# dump at 2982
# dump at 2983
# dump at 2984
# dump at 2985
# dump at 2986
# dump at 2987
# dump at 2988
# dump at 2989
# dump at 2990
# dump at 2991
# dump at 2992
# dump at 2993
# dump at 2994
# dump at 2995
# dump at 2996
# dump at 2997
# dump at 2998
# dump at 2999
# dump at 3000
# dump at 3001
# dump at 3002
# dump at 3003
# dump at 3004
# dump at 3005
# dump at 3006
# dump at 3007
# dump at 3008
# dump at 3009
# dump at 3010
# dump at 3011
# dump at 3012
# dump at 3013
# dump at 3014
# dump at 3015
# dump at 3016
# dump at 3017
# dump at 3018
# dump at 3019
# dump at 3020
# dump at 3021
# dump at 3022
# dump at 3023
# dump at 3024
# dump at 3025
# dump at 3026
# dump at 3027
# dump at 3028
# dump at 3029
# dump at 3030
# dump at 3031
# dump at 3032
# dump at 3033
# dump at 3034
# dump at 3035
# dump at 3036
# dump at 3037
# dump at 3038
# dump at 3039
# dump at 3040
# dump at 3041
# dump at 3042
# dump at 3043
# dump at 3044
# dump at 3045
# dump at 3046
# dump at 3047
# dump at 3048
# dump at 3049
# dump at 3050
# dump at 3051
# dump at 3052
# dump at 3053
# dump at 3054
# dump at 3055
# dump at 3056
# dump at 3057
# dump at 3058
# dump at 3059
# dump at 3060
# dump at 3061
# dump at 3062
# dump at 3063
# dump at 3064
# dump at 3065
# dump at 3066
# dump at 3067
# dump at 3068
# dump at 3069
# dump at 3070
# dump at 3071
# dump at 3072
# dump at 3073
# dump at 3074
# dump at 3075
# dump at 3076
# dump at 3077
# dump at 3078
# dump at 3079
# dump at 3080
# dump at 3081
# dump at 3082
# dump at 3083
# dump at 3084
# dump at 3085
# dump at 3086
# dump at 3087
# dump at 3088
# dump at 3089
# dump at 3090
# dump at 3091
# dump at 3092
# dump at 3093
# dump at 3094
# dump at 3095
# dump at 3096
# dump at 3097
# dump at 3098
# dump at 3099
# dump at 3100
# dump at 3101
# dump at 3102
# dump at 3103
# dump at 3104
# dump at 3105
# dump at 3106
# dump at 3107
# dump at 3108
# dump at 3109
# dump at 3110
# dump at 3111
# dump at 3112
# dump at 3113
# dump at 3114
# dump at 3115
# dump at 3116
# dump at 3117
# dump at 3118
# dump at 3119
# dump at 3120
# dump at 3121
# dump at 3122
# dump at 3123
# dump at 3124
# dump at 3125
# dump at 3126
# dump at 3127
# dump at 3128
# dump at 3129
# dump at 3130
# dump at 3131
# dump at 3132
# dump at 3133
# dump at 3134
# dump at 3135
# dump at 3136
# dump at 3137
# dump at 3138
# dump at 3139
# dump at 3140
# dump at 3141
# dump at 3142
# dump at 3143
# dump at 3144
# dump at 3145
# dump at 3146
# dump at 3147
# dump at 3148
# dump at 3149
# dump at 3150
# dump at 3151
# dump at 3152
# dump at 3153
# dump at 3154
# dump at 3155
# dump at 3156
# dump at 3157
# dump at 3158
# dump at 3159
# dump at 3160
# dump at 3161
# dump at 3162
# dump at 3163
# dump at 3164
# dump at 3165
# dump at 3166
# dump at 3167
# dump at 3168
# dump at 3169
# dump at 3170
# dump at 3171
# dump at 3172
# dump at 3173
# dump at 3174
# dump at 3175
# dump at 3176
# dump at 3177
# dump at 3178
# dump at 3179
# dump at 3180
# dump at 3181
# dump at 3182
# dump at 3183
# dump at 3184
# dump at 3185
# dump at 3186
# dump at 3187
# dump at 3188
# dump at 3189
# dump at 3190
# dump at 3191
# dump at 3192
# dump at 3193
# dump at 3194
# dump at 3195
# dump at 3196
# dump at 3197
# dump at 3198
# dump at 3199
# dump at 3200
# dump at 3201
# dump at 3202
# dump at 3203
# dump at 3204
# dump at 3205
# dump at 3206
# dump at 3207
# dump at 3208
# dump at 3209
# dump at 3210
# dump at 3211
# dump at 3212
# dump at 3213
# dump at 3214
# dump at 3215
# dump at 3216
# dump at 3217
# dump at 3218
# dump at 3219
# dump at 3220
# dump at 3221
# dump at 3222
# dump at 3223
# dump at 3224
# dump at 3225
# dump at 3226
# dump at 3227
# dump at 3228
# dump at 3229
# dump at 3230
# dump at 3231
# dump at 3232
# dump at 3233
# dump at 3234
# dump at 3235
# dump at 3236
# dump at 3237
# dump at 3238
# dump at 3239
# dump at 3240
# dump at 3241
# dump at 3242
# dump at 3243
# dump at 3244
# dump at 3245
# dump at 3246
# dump at 3247
# dump at 3248
# dump at 3249
# dump at 3250
# dump at 3251
# dump at 3252
# dump at 3253
# dump at 3254
# dump at 3255
# dump at 3256
# dump at 3257
# dump at 3258
# dump at 3259
# dump at 3260
# dump at 3261
# dump at 3262
# dump at 3263
# dump at 3264
# dump at 3265
# dump at 3266
# dump at 3267
# dump at 3268
# dump at 3269
# dump at 3270
# dump at 3271
# dump at 3272
# dump at 3273
# dump at 3274
# dump at 3275
# dump at 3276
# dump at 3277
# dump at 3278
# dump at 3279
# dump at 3280
# dump at 3281
# dump at 3282
# dump at 3283
# dump at 3284
# dump at 3285
# dump at 3286
# dump at 3287
# dump at 3288
# dump at 3289
# dump at 3290
# dump at 3291
# dump at 3292
# dump at 3293
# dump at 3294
# dump at 3295
# dump at 3296
# dump at 3297
# dump at 3298
# dump at 3299
# dump at 3300
# dump at 3301
# dump at 3302
# dump at 3303
# dump at 3304
# dump at 3305
# dump at 3306
# dump at 3307
# dump at 3308
# dump at 3309
# dump at 3310
# dump at 3311
# dump at 3312
# dump at 3313
# dump at 3314
# dump at 3315
# dump at 3316
# dump at 3317
# dump at 3318
# dump at 3319
# dump at 3320
# dump at 3321
# dump at 3322
# dump at 3323
# dump at 3324
# dump at 3325
# dump at 3326
# dump at 3327
# dump at 3328
# dump at 3329
# dump at 3330
# dump at 3331
# dump at 3332
# dump at 3333
# dump at 3334
# dump at 3335
# dump at 3336
# dump at 3337
# dump at 3338
# dump at 3339
# dump at 3340
# dump at 3341
# dump at 3342
# dump at 3343
# dump at 3344
# dump at 3345
# dump at 3346
# dump at 3347
# dump at 3348
# dump at 3349
# dump at 3350
# dump at 3351
# dump at 3352
# dump at 3353
# dump at 3354
# dump at 3355
# dump at 3356
# dump at 3357
# dump at 3358
# dump at 3359
# dump at 3360
# dump at 3361
# dump at 3362
# dump at 3363
# dump at 3364
# dump at 3365
# dump at 3366
# dump at 3367
# dump at 3368
# dump at 3369
# dump at 3370
# dump at 3371
# dump at 3372
# dump at 3373
# dump at 3374
# dump at 3375
# dump at 3376
# dump at 3377
# dump at 3378
# dump at 3379
# dump at 3380
# dump at 3381
# dump at 3382
# dump at 3383
# dump at 3384
# dump at 3385
# dump at 3386
# dump at 3387
# dump at 3388
# dump at 3389
# dump at 3390
# dump at 3391
# dump at 3392
# dump at 3393
# dump at 3394
# dump at 3395
# dump at 3396
# dump at 3397
# dump at 3398
# dump at 3399
# dump at 3400
# dump at 3401
# dump at 3402
# dump at 3403
# dump at 3404
# dump at 3405
# dump at 3406
# dump at 3407
# dump at 3408
# dump at 3409
# dump at 3410
# dump at 3411
# dump at 3412
# dump at 3413
# dump at 3414
# dump at 3415
# dump at 3416
# dump at 3417
# dump at 3418
# dump at 3419
# dump at 3420
# dump at 3421
# dump at 3422
# dump at 3423
# dump at 3424
# dump at 3425
# dump at 3426
# dump at 3427
# dump at 3428
# dump at 3429
# dump at 3430
# dump at 3431
# dump at 3432
# dump at 3433
# dump at 3434
# dump at 3435
# dump at 3436
# dump at 3437
# dump at 3438
# dump at 3439
# dump at 3440
# dump at 3441
# dump at 3442
# dump at 3443
# dump at 3444
# dump at 3445
# dump at 3446
# dump at 3447
# dump at 3448
# dump at 3449
# dump at 3450
# dump at 3451
# dump at 3452
# dump at 3453
# dump at 3454
# dump at 3455
# dump at 3456
# dump at 3457
# dump at 3458
# dump at 3459
# dump at 3460
# dump at 3461
# dump at 3462
# dump at 3463
# dump at 3464
# dump at 3465
# dump at 3466
# dump at 3467
# dump at 3468
# dump at 3469
# dump at 3470
# dump at 3471
# dump at 3472
# dump at 3473
# dump at 3474
# dump at 3475
# dump at 3476
# dump at 3477
# dump at 3478
# dump at 3479
# dump at 3480
# dump at 3481
# dump at 3482
# dump at 3483
# dump at 3484
# dump at 3485
# dump at 3486
# dump at 3487
# dump at 3488
# dump at 3489
# dump at 3490
# dump at 3491
# dump at 3492
# dump at 3493
# dump at 3494
# dump at 3495
# dump at 3496
# dump at 3497
# dump at 3498
# dump at 3499
# dump at 3500
# dump at 3501
# dump at 3502
# dump at 3503
# dump at 3504
# dump at 3505
# dump at 3506
# dump at 3507
# dump at 3508
# dump at 3509
# dump at 3510
# dump at 3511
# dump at 3512
# dump at 3513
# dump at 3514
# dump at 3515
# dump at 3516
# dump at 3517
# dump at 3518
# dump at 3519
# dump at 3520
# dump at 3521
# dump at 3522
# dump at 3523
# dump at 3524
# dump at 3525
# dump at 3526
# dump at 3527
# dump at 3528
# dump at 3529
# dump at 3530
# dump at 3531
# dump at 3532
# dump at 3533
# dump at 3534
# dump at 3535
# dump at 3536
# dump at 3537
# dump at 3538
# dump at 3539
# dump at 3540
# dump at 3541
# dump at 3542
# dump at 3543
# dump at 3544
# dump at 3545
# dump at 3546
# dump at 3547
# dump at 3548
# dump at 3549
# dump at 3550
# dump at 3551
# dump at 3552
# dump at 3553
# dump at 3554
# dump at 3555
# dump at 3556
# dump at 3557
# dump at 3558
# dump at 3559
# dump at 3560
# dump at 3561
# dump at 3562
# dump at 3563
# dump at 3564
# dump at 3565
# dump at 3566
# dump at 3567
# dump at 3568
# dump at 3569
# dump at 3570
# dump at 3571
# dump at 3572
# dump at 3573
# dump at 3574
# dump at 3575
# dump at 3576
# dump at 3577
# dump at 3578
# dump at 3579
# dump at 3580
# dump at 3581
# dump at 3582
# dump at 3583
# dump at 3584
# dump at 3585
# dump at 3586
# dump at 3587
# dump at 3588
# dump at 3589
# dump at 3590
# dump at 3591
# dump at 3592
# dump at 3593
# dump at 3594
# dump at 3595
# dump at 3596
# dump at 3597
# dump at 3598
# dump at 3599
# dump at 3600
# dump at 3601
# dump at 3602
# dump at 3603
# dump at 3604
# dump at 3605
# dump at 3606
# dump at 3607
# dump at 3608
# dump at 3609
# dump at 3610
# dump at 3611
# dump at 3612
# dump at 3613
# dump at 3614
# dump at 3615
# dump at 3616
# dump at 3617
# dump at 3618
# dump at 3619
# dump at 3620
# dump at 3621
# dump at 3622
# dump at 3623
# dump at 3624
# dump at 3625
# dump at 3626
# dump at 3627
# dump at 3628
# dump at 3629
# dump at 3630
# dump at 3631
# dump at 3632
# dump at 3633
# dump at 3634
# dump at 3635
# dump at 3636
# dump at 3637
# dump at 3638
# dump at 3639
# dump at 3640
# dump at 3641
# dump at 3642
# dump at 3643
# dump at 3644
# dump at 3645
# dump at 3646
# dump at 3647
# dump at 3648
# dump at 3649
# dump at 3650
# dump at 3651
# dump at 3652
# dump at 3653
# dump at 3654
# dump at 3655
# dump at 3656
# dump at 3657
# dump at 3658
# dump at 3659
# dump at 3660
# dump at 3661
# dump at 3662
# dump at 3663
# dump at 3664
# dump at 3665
# dump at 3666
# dump at 3667
# dump at 3668
# dump at 3669
# dump at 3670
# dump at 3671
# dump at 3672
# dump at 3673
# dump at 3674
# dump at 3675
# dump at 3676
# dump at 3677
# dump at 3678
# dump at 3679
# dump at 3680
# dump at 3681
# dump at 3682
# dump at 3683
# dump at 3684
# dump at 3685
# dump at 3686
# dump at 3687
# dump at 3688
# dump at 3689
# dump at 3690
# dump at 3691
# dump at 3692
# dump at 3693
# dump at 3694
# dump at 3695
# dump at 3696
# dump at 3697
# dump at 3698
# dump at 3699
# dump at 3700
# dump at 3701
# dump at 3702
# dump at 3703
# dump at 3704
# dump at 3705
# dump at 3706
# dump at 3707
# dump at 3708
# dump at 3709
# dump at 3710
# dump at 3711
# dump at 3712
# dump at 3713
# dump at 3714
# dump at 3715
# dump at 3716
# dump at 3717
# dump at 3718
# dump at 3719
# dump at 3720
# dump at 3721
# dump at 3722
# dump at 3723
# dump at 3724
# dump at 3725
# dump at 3726
# dump at 3727
# dump at 3728
# dump at 3729
# dump at 3730
# dump at 3731
# dump at 3732
# dump at 3733
# dump at 3734
# dump at 3735
# dump at 3736
# dump at 3737
# dump at 3738
# dump at 3739
# dump at 3740
# dump at 3741
# dump at 3742
# dump at 3743
# dump at 3744
# dump at 3745
# dump at 3746
# dump at 3747
# dump at 3748
# dump at 3749
# dump at 3750
# dump at 3751
# dump at 3752
# dump at 3753
# dump at 3754
# dump at 3755
# dump at 3756
# dump at 3757
# dump at 3758
# dump at 3759
# dump at 3760
# dump at 3761
# dump at 3762
# dump at 3763
# dump at 3764
# dump at 3765
# dump at 3766
# dump at 3767
# dump at 3768
# dump at 3769
# dump at 3770
# dump at 3771
# dump at 3772
# dump at 3773
# dump at 3774
# dump at 3775
# dump at 3776
# dump at 3777
# dump at 3778
# dump at 3779
# dump at 3780
# dump at 3781
# dump at 3782
# dump at 3783
# dump at 3784
# dump at 3785
# dump at 3786
# dump at 3787
# dump at 3788
# dump at 3789
# dump at 3790
# dump at 3791
# dump at 3792
# dump at 3793
# dump at 3794
# dump at 3795
# dump at 3796
# dump at 3797
# dump at 3798
# dump at 3799
# dump at 3800
# dump at 3801
# dump at 3802
# dump at 3803
# dump at 3804
# dump at 3805
# dump at 3806
# dump at 3807
# dump at 3808
# dump at 3809
# dump at 3810
# dump at 3811
# dump at 3812
# dump at 3813
# dump at 3814
# dump at 3815
# dump at 3816
# dump at 3817
# dump at 3818
# dump at 3819
# dump at 3820
# dump at 3821
# dump at 3822
# dump at 3823
# dump at 3824
# dump at 3825
# dump at 3826
# dump at 3827
# dump at 3828
# dump at 3829
# dump at 3830
# dump at 3831
# dump at 3832
# dump at 3833
# dump at 3834
# dump at 3835
# dump at 3836
# dump at 3837
# dump at 3838
# dump at 3839
# dump at 3840
# dump at 3841
# dump at 3842
# dump at 3843
# dump at 3844
# dump at 3845
# dump at 3846
# dump at 3847
# dump at 3848
# dump at 3849
# dump at 3850
# dump at 3851
# dump at 3852
# dump at 3853
# dump at 3854
# dump at 3855
# dump at 3856
# dump at 3857
# dump at 3858
# dump at 3859
# dump at 3860
# dump at 3861
# dump at 3862
# dump at 3863
# dump at 3864
# dump at 3865
# dump at 3866
# dump at 3867
# dump at 3868
# dump at 3869
# dump at 3870
# dump at 3871
# dump at 3872
# dump at 3873
# dump at 3874
# dump at 3875
# dump at 3876
# dump at 3877
# dump at 3878
# dump at 3879
# dump at 3880
# dump at 3881
# dump at 3882
# dump at 3883
# dump at 3884
# dump at 3885
# dump at 3886
# dump at 3887
# dump at 3888
# dump at 3889
# dump at 3890
# dump at 3891
# dump at 3892
# dump at 3893
# dump at 3894
# dump at 3895
# dump at 3896
# dump at 3897
# dump at 3898
# dump at 3899
# dump at 3900
# dump at 3901
# dump at 3902
# dump at 3903
# dump at 3904
# dump at 3905
# dump at 3906
# dump at 3907
# dump at 3908
# dump at 3909
# dump at 3910
# dump at 3911
# dump at 3912
# dump at 3913
# dump at 3914
# dump at 3915
# dump at 3916
# dump at 3917
# dump at 3918
# dump at 3919
# dump at 3920
# dump at 3921
# dump at 3922
# dump at 3923
# dump at 3924
# dump at 3925
# dump at 3926
# dump at 3927
# dump at 3928
# dump at 3929
# dump at 3930
# dump at 3931
# dump at 3932
# dump at 3933
# dump at 3934
# dump at 3935
# dump at 3936
# dump at 3937
# dump at 3938
# dump at 3939
# dump at 3940
# dump at 3941
# dump at 3942
# dump at 3943
# dump at 3944
# dump at 3945
# dump at 3946
# dump at 3947
# dump at 3948
# dump at 3949
# dump at 3950
# dump at 3951
# dump at 3952
# dump at 3953
# dump at 3954
# dump at 3955
# dump at 3956
# dump at 3957
# dump at 3958
# dump at 3959
# dump at 3960
# dump at 3961
# dump at 3962
# dump at 3963
# dump at 3964
# dump at 3965
# dump at 3966
# dump at 3967
# dump at 3968
# dump at 3969
# dump at 3970
# dump at 3971
# dump at 3972
# dump at 3973
# dump at 3974
# dump at 3975
# dump at 3976
# dump at 3977
# dump at 3978
# dump at 3979
# dump at 3980
# dump at 3981
# dump at 3982
# dump at 3983
# dump at 3984
# dump at 3985
# dump at 3986
# dump at 3987
# dump at 3988
# dump at 3989
# dump at 3990
# dump at 3991
# dump at 3992
# dump at 3993
# dump at 3994
# dump at 3995
# dump at 3996
# dump at 3997
# dump at 3998
# dump at 3999
# dump at 4000
# dump at 4001
# dump at 4002
# dump at 4003
# dump at 4004
# dump at 4005
# dump at 4006
# dump at 4007
# dump at 4008
# dump at 4009
# dump at 4010
# dump at 4011
# dump at 4012
# dump at 4013
# dump at 4014
# dump at 4015
# dump at 4016
# dump at 4017
# dump at 4018
# dump at 4019
# dump at 4020
# dump at 4021
# dump at 4022
# dump at 4023
# dump at 4024
# dump at 4025
# dump at 4026
# dump at 4027
# dump at 4028
# dump at 4029
# dump at 4030
# dump at 4031
# dump at 4032
# dump at 4033
# dump at 4034
# dump at 4035
# dump at 4036
# dump at 4037
# dump at 4038
# dump at 4039
# dump at 4040
# dump at 4041
# dump at 4042
# dump at 4043
# dump at 4044
# dump at 4045
# dump at 4046
# dump at 4047
# dump at 4048
# dump at 4049
# dump at 4050
# dump at 4051
# dump at 4052
# dump at 4053
# dump at 4054
# dump at 4055
# dump at 4056
# dump at 4057
# dump at 4058
# dump at 4059
# dump at 4060
# dump at 4061
# dump at 4062
# dump at 4063
# dump at 4064
# dump at 4065
# dump at 4066
# dump at 4067
# dump at 4068
# dump at 4069
# dump at 4070
# dump at 4071
# dump at 4072
# dump at 4073
# dump at 4074
# dump at 4075
# dump at 4076
# dump at 4077
# dump at 4078
# dump at 4079
# dump at 4080
# dump at 4081
# dump at 4082
# dump at 4083
# dump at 4084
# dump at 4085
# dump at 4086
# dump at 4087
# dump at 4088
# dump at 4089
# dump at 4090
# dump at 4091
# dump at 4092
# dump at 4093
# dump at 4094
# dump at 4095
# dump at 4096
# dump at 4097
# dump at 4098
# dump at 4099
# dump at 4100
# dump at 4101
# dump at 4102
# dump at 4103
# dump at 4104
# dump at 4105
# dump at 4106
# dump at 4107
# dump at 4108
# dump at 4109
# dump at 4110
# dump at 4111
# dump at 4112
# dump at 4113
# dump at 4114
# dump at 4115
# dump at 4116
# dump at 4117
# dump at 4118
# dump at 4119
# dump at 4120
# dump at 4121
# dump at 4122
# dump at 4123
# dump at 4124
# dump at 4125
# dump at 4126
# dump at 4127
# dump at 4128
# dump at 4129
# dump at 4130
# dump at 4131
# dump at 4132
# dump at 4133
# dump at 4134
# dump at 4135
# dump at 4136
# dump at 4137
# dump at 4138
# dump at 4139
# dump at 4140
# dump at 4141
# dump at 4142
# dump at 4143
# dump at 4144
# dump at 4145
# dump at 4146
# dump at 4147
# dump at 4148
# dump at 4149
# dump at 4150
# dump at 4151
# dump at 4152
# dump at 4153
# dump at 4154
# dump at 4155
# dump at 4156
# dump at 4157
# dump at 4158
# dump at 4159
# dump at 4160
# dump at 4161
# dump at 4162
# dump at 4163
# dump at 4164
# dump at 4165
# dump at 4166
# dump at 4167
# dump at 4168
# dump at 4169
# dump at 4170
# dump at 4171
# dump at 4172
# dump at 4173
# dump at 4174
# dump at 4175
# dump at 4176
# dump at 4177
# dump at 4178
# dump at 4179
# dump at 4180
# dump at 4181
# dump at 4182
# dump at 4183
# dump at 4184
# dump at 4185
# dump at 4186
# dump at 4187
# dump at 4188
# dump at 4189
# dump at 4190
# dump at 4191
# dump at 4192
# dump at 4193
# dump at 4194
# dump at 4195
# dump at 4196
# dump at 4197
# dump at 4198
# dump at 4199
# [[40, 1166], [[1722, 68, 641, 1723, 23, 642, 8, 41, 6, 24, 19, 3, 18, 22, 172, 746, 1], [42, 3, 46, 32, 492, 10, 79, 3, 438, 37, 1724, 20, 2, 19, 9, 557, 20, 4, 2, 82, 1725, 51, 26, 32, 1726, 25, 239, 4, 44, 32, 39, 254, 1], [143, 83, 747, 79, 643, 748, 3, 1169, 1727, 902, 13, 1728, 3, 4, 1729, 62, 133, 25, 2, 112, 1], [11, 16, 9, 903, 20, 80, 493, 55, 80, 904, 4, 2, 394, 558, 1], [439, 45, 21, 3, 44, 1170, 8, 76, 72, 2, 178, 905, 1], [1730, 23, 19, 14]], [1, 3, 3, 3, 3, 1]]
# [['restaurant', 'general'], [['Judging', 'from', 'previous', 'posts', 'this', 'used', 'to', 'be', 'a', 'good', 'place', ',', 'but', 'not', 'any', 'longer', '.'], ['We', ',', 'there', 'were', 'four', 'of', 'us', ',', 'arrived', 'at', 'noon', '-', 'the', 'place', 'was', 'empty', '-', 'and', 'the', 'staff', 'acted', 'like', 'we', 'were', 'imposing', 'on', 'them', 'and', 'they', 'were', 'very', 'rude', '.'], ['They', 'never', 'brought', 'us', 'complimentary', 'noodles', ',', 'ignored', 'repeated', 'requests', 'for', 'sugar', ',', 'and', 'threw', 'our', 'dishes', 'on', 'the', 'table', '.'], ['The', 'food', 'was', 'lousy', '-', 'too', 'sweet', 'or', 'too', 'salty', 'and', 'the', 'portions', 'tiny', '.'], ['After', 'all', 'that', ',', 'they', 'complained', 'to', 'me', 'about', 'the', 'small', 'tip', '.'], ['Avoid', 'this', 'place', '!']], [1, 3, 3, 3, 3, 1]]
