# %%
# !pip install -U -q PyDrive
import os
from pydrive.auth import GoogleAuth
from pydrive.drive import GoogleDrive
from google.colab import auth
from oauth2client.client import GoogleCredentials

auth.authenticate_user()
gauth = GoogleAuth()
gauth.credentials = GoogleCredentials.get_application_default()
drive = GoogleDrive(gauth)
# Out:
#      |████████████████████████████████| 993kB 2.8MB/s
#   Building wheel for PyDrive (setup.py) ... done

# %%
project_module = drive.CreateFile({'id':'[14GgbYQeWJRzgSvf5VJ3z3g_xCOVrdrgo]'})

# %%
# !git clone https://gitlab.lrz.de/dugarsumit/master-thesis-sumit.git
# Out:
# Cloning into 'master-thesis-sumit'...
# fatal: could not read Username for 'https://gitlab.lrz.de': No such device or address
